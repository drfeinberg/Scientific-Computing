# %% [markdown]
# # Debugging
# <div class="alert alert-success">
# Debugging is the process of finding and fixing errors in a computer program.
# </div>
#
# Different kinds of errors can occur in a program, and it is useful to distinguish among them in order to track them down more quickly.

# %% [markdown]
# # Different types of Errors
# There are many different types of errors in Python.  Here is a nonexhaustive list of popular errors.
#
# - Syntax errors
# - Indentation error
# - Zero division error
# - Name error
# - Index error
# - Value error
# - Type error

# %% [markdown]
# ## Syntax Errors
#
# - Syntax errors are usually easy to fix once you figure out what they are.
# - Unfortunately, the error messages are often not helpful.
# - The most common messages are `SyntaxError: invalid syntax` and `SyntaxError:invalid token`
#     - Neither are very informative
# - The message does tell you where in the program the problem occurred.
#     - Actually, it tells you where Python noticed a problem, which is not necessarily where the error is.
#     - Sometimes the error is prior to the location of the error message, often on the preceding line.
# - If you are building the program incrementally, you should have a good idea about where the error is.
#     - It will be in the last line you added
# - If you are copying code from a book, or the internet, start by comparing your code to the book's or website's code very carefully.
#     - Check every character.
#     - Remember that the book or website might be wrong, or using an incompatible software version
#         - If you see something that looks like a syntax error, it might not be your fault
# - Syntax errors are produced by Python when it is translating the source code into byte code.
#     - They usually indicate that there is something wrong with the syntax of the program.

# %% [markdown]
# ### Syntax Error Examples

# %% [markdown]
# #### Missing colon

# %%
if True
    print('Yep.')
# Out:
#   File "<ipython-input-2-84adba9b209c>", line 1
#     if True
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# You can see that Python is trying really hard to show you where the error is.  It put the `^` symbol right where it's missing something.

# %% [markdown]
# #### Forgot to close quotes

# %%
name = 'Dr Feinberg
# Out:
#   File "<ipython-input-3-f36633c8afd8>", line 1
#     name = 'Dr Feinberg
#                       ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #### Forgot to close parentheses

# %%
print('My Name is; My name is; My name is Slim Shady'
# Out:
#   File "<ipython-input-14-84ddbb59fdf6>", line 1
#     print('My Name is; My name is; My name is Slim Shady'
#                                                          ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# #### Typed your operator backwards... should be `+=`, not `=+`

# %%
 6 =+ 1
# Out:
#   File "<ipython-input-15-353f08094bc6>", line 1
#     6 =+ 1
# SyntaxError: can't assign to literal

# %% [markdown]
# # Avoiding common syntax errors:
#
# - Don't use `def` or `print` or something Python has reserved as your variable name
# - Check that you have a colon at the end of the header of statement like `for`, `while`, `if`, and `def`.
# - Check that indentation is correct.
#     - In jupyter notebook, you can indent with `tab`, and you can also unindent with `shift+tab`
# - Make sure that any quotes, parentheses, blocks, etc are closed properly.
#     - Software can change the colour of the text
#     - Software can't tell you if you are making a semantic error.

# %% [markdown]
# ## More common errors...

# %% [markdown]
# ### Indentation Error Example

# %%
my_list = [1, 2]
for value in my_list:
print(value)
# Out:
#   File "<ipython-input-16-6b38a7bbe4d8>", line 3
#     print(value)
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# ### ZeroDivisionError
#
# ZeroDivisionError occurs when you try to divide by zero. There are other math errors that occur when trying to do illegal mathematical operations.  Don't worry, you won't go to jail if you do illegal mathematical operations.  Your program won't work though.

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-bc757c3fda29> in <module>()
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Name Error
#
# #### NameError occurs when you try to access a name that Python does not know.

# %% [markdown]
# #### For example, if you typo a name, you will get a NameError

# %%
variable = 12
varaible
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d676d3304780> in <module>
#       1 variable = 12
# ----> 2 varaible
#
# NameError: name 'varaible' is not defined

# %% [markdown]
# #### You also get a name error if you try to use the wrong operator for assignment

# %%
new_variable == 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4f05423dede6> in <module>()
#       1 # You also get a name error if you try to use the wrong operator for assignment
# ----> 2 new_variable == 1
#
# NameError: name 'new_variable' is not defined

# %% [markdown]
# #### Name errors can also occur if you make certain typos for built-in commands:

# %%
if Ture:
    print('The truth is out there.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-375a130a2eea> in <module>
# ----> 1 if Ture:
#       2     print('The truth is out there.')
#
# NameError: name 'Ture' is not defined

# %% [markdown]
# ### IndexError
#
# IndexError occurs when you try to access an index that doesn't exist.  You probably think the index does exist, otherwise you wouldn't have an error, so you have to get out of your head and realize Python is trying to tell you that the item you are trying to reference doesn't exist.

# %%
my_list = [1, 2, 3]
my_list[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-2c2a83518cf2> in <module>()
#       1 my_list = [1, 2, 3]
# ----> 2 my_list[5]
#
# IndexError: list index out of range

# %%
# Relatedly, 'KeyError' occurs if you ask for a dictionary key that doesn't exist
my_dictionary = {'name1' : 1, 'name2' : 2}
my_dictionary['name3']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-84a1c00e4833> in <module>()
#       1 # Relatedly, 'KeyError' occurs if you ask for a dictionary key that doesn't exist
#       2 my_dictionary = {'name1' : 1, 'name2' : 2}
# ----> 3 my_dictionary['name3']
#
# KeyError: 'name3'

# %% [markdown]
# ### ValueError
#
# ValueError occurs when you try to use an illegal value for something.

# %%
int('cat')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1c6b28888bbe> in <module>()
# ----> 1 int('cat')
#
# ValueError: invalid literal for int() with base 10: 'cat'

# %%
my_list = [1, 2, 3]
my_list.remove(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f00634ed638b> in <module>()
#       1 my_list = [1, 2, 3]
# ----> 2 my_list.remove(0)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### TypeErrors
# Type errors occur when you do something illegal to that DataType.

# %%
'a_string' + 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-57c293ee5895> in <module>
# ----> 1 'a_string' + 12
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### Key error
# - You are trying to access an element of a dictionary using a key value that
# the dictionary does not contain.

# %%
dict = {"yellow": 4, "green": 3, "elbow": 9}

print(dict['granola'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-a0122c669b84> in <module>()
#       1 dict = {"yellow": 4, "green": 3, "elbow": 9}
#       2
# ----> 3 print(dict['granola'])
#
# KeyError: 'granola'

# %% [markdown]
# ### AttributeError
# You are trying to access an attribute or method that does not exist.

# %%
brain_region = "hypothalamus"
brain_region.stain()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c623bbb627fc> in <module>()
#       1 brain_region = "hypothalamus"
# ----> 2 brain_region.stain()
#
# AttributeError: 'str' object has no attribute 'stain'

# %% [markdown]
# Here the problem isn't that we're trying to add to a string, it's that we're trying to add a number (in particular, an integer) to a string.

# %% [markdown]
# # Finding your errors
#
# ## Finding an error isn't easy.  Even when Python tells you about your error, sometimes we can spend hours looking for a typo.
#
# So how can we do this?

# %% [markdown]
# ## Stack Trace
#
# A stack trace tells you where the error occured in the code, and traces that back all the way to the root of the problem.

# %%
def running_sums(list):
    running_sum = 0
    for val in my_list:

        if val % 2 == 0:
            temp = val / (val - 4)
            running_sum += temp
    return running_sums()


my_list = [1, 2, 3, 4, 5]
sums = running_sums(my_list)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-e2420ca48c2f> in <module>
#      10
#      11 my_list = [1, 2, 3, 4, 5]
# ---> 12 sums = running_sums(my_list)
#
# <ipython-input-4-e2420ca48c2f> in running_sums(list)
#       4
#       5         if val % 2 == 0:
# ----> 6             temp = val / (val - 4)
#       7             running_sum += temp
#       8     return running_sums()
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #### The error message displayed has two parts.
# - First, it shows:
# `
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-e2420ca48c2f> in <module>
#      10
#      11 my_list = [1, 2, 3, 4, 5]
# ---> 12 sums = running_sums(my_list)
# `
#
# - It found an error on line 12 where it drew the arrow. `
# - The code: `sums = running_sums(my_list)` failed to execute
#
# #### The traceback goes deeper
# <code>
# &lt;ipython-input-4-e2420ca48c2f> in running_sums(list)
#       4
#       5         if val % 2 == 0:
# ----> 6             temp = val / (val - 4)
#       7             running_sum += temp
#       8     return running_sums()
#
# ZeroDivisionError: division by zero
# </code>
#
# Here, Python traces back the error to line 6 of the `running_sums` function.
# When we get to the number 4 on the list, 4 -4 = 0, and we are trying to divide by 0.
#
# Later, we will learn how to `step through the code` to figure out this type of error.

# %% [markdown]
# # Stepping through code
#
# Stepping through the code is going line by line, making sure you see the contents of each variable and how that information flows through the program in order to diagnose an error.

# %% [markdown]
# Here, you could use more advanced coding software that has debugging tools, or you could write some easy `print()` statements into the code to see what's goin on along the way.

# %% [markdown]
# ## Stepping through code example
#
# Here we'll use the example from Stack Trace to step through our code and figure out how the value 4 is causing a divide-by-zero error.

# %%
def running_sums(list):  
    running_sum = 0
    print("Initial value of running_sum: ", running_sum) # Check if the value of running_sum is 0
    for val in my_list:

        if val % 2 == 0:
            temp = val / (val - 4)
            running_sum += temp
    return running_sums()


my_list = [1, 2, 3, 4, 5]
sums = running_sums(my_list)
# Out:
# ('Initial value of running_sum: ', 0)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-70b6f62cd137> in <module>()
#      11
#      12 my_list = [1, 2, 3, 4, 5]
# ---> 13 sums = running_sums(my_list)
#
# <ipython-input-7-70b6f62cd137> in running_sums(list)
#       5
#       6         if val % 2 == 0:
# ----> 7             temp = val / (val - 4)
#       8             running_sum += temp
#       9     return running_sums()
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# Great.  We know that worked. On to the next part.

# %%
def running_sums(list):  
    running_sum = 0
    print("Initial value of running_sum: ", running_sum) # Check if the value of running_sum is 0
    for val in my_list:
        print("val: ", val)  # show us the value of val so we can see if that's causing the error
        if val % 2 == 0:
            temp = val / (val - 4)
            running_sum += temp
    return running_sums()


my_list = [1, 2, 3, 4, 5]
sums = running_sums(my_list)
# Out:
# ('Initial value of running_sum: ', 0)
# ('val: ', 1)
# ('val: ', 2)
# ('val: ', 3)
# ('val: ', 4)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-5e379a74082c> in <module>()
#      11
#      12 my_list = [1, 2, 3, 4, 5]
# ---> 13 sums = running_sums(my_list)
#
# <ipython-input-8-5e379a74082c> in running_sums(list)
#       5         print("val: ", val)  # show us the value of val so we can see if that's causing the error
#       6         if val % 2 == 0:
# ----> 7             temp = val / (val - 4)
#       8             running_sum += temp
#       9     return running_sums()
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# Look, the program stopped running when val was 4.  Let's keep going to see why 4 is making it crash.

# %%
def running_sums(list):  
    running_sum = 0
    print("Initial value of running_sum: ", running_sum) # Check if the value of running_sum is 0
    for val in my_list:
        print("val: ", val)  # show us the value of val so we can see if that's causing the error
        if val % 2 == 0:
            temp = val / (val - 4)
            print("temp: ", temp) # Show us the value of temp
            running_sum += temp
    return running_sums()


my_list = [1, 2, 3, 4, 5]
sums = running_sums(my_list)
# Out:
# ('Initial value of running_sum: ', 0)
# ('val: ', 1)
# ('val: ', 2)
# ('temp: ', -1)
# ('val: ', 3)
# ('val: ', 4)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-e2ce0927a530> in <module>()
#      12
#      13 my_list = [1, 2, 3, 4, 5]
# ---> 14 sums = running_sums(my_list)
#
# <ipython-input-9-e2ce0927a530> in running_sums(list)
#       5         print("val: ", val)  # show us the value of val so we can see if that's causing the error
#       6         if val % 2 == 0:
# ----> 7             temp = val / (val - 4)
#       8             print("temp: ", temp)
#       9             running_sum += temp
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# Oh no!  It stopped before we got the value of temp.  That means we need to look at the equation in `temp` to see what's going on.  Remember that the program stopped when `val == 4`.
#
# - Break the equation down into parts so you can see what it's doing.
# - Plug in the value where it stopped working
#     - in this example that's `4`

# %%
val = 4
numerator = val
print("numerator: ", numerator)
denominator = (val - 4)
print("denominator: ", denominator)
# Out:
# ('numerator: ', 4)
# ('denominator: ', 0)

# %% [markdown]
# ### Explanation:
# When `val = 4`, the denominator becomes: `4 -4 = 0`. When the value is 4, we are trying to divide 4 into zero parts, which is impossible in Python.  This causes the error.

# %% [markdown]
# ### Don't forget to clean up!
# When your're done debugging, make sure you get rid of all of those print statements that you used to debug your program.
#
#
# ### Hurray!
#
# We stepped through the code and figured out the error by breaking the code down into it's pieces and seeing what each part does.

# %% [markdown]
# # Programming so the user doesn't see any errors and so errors don't break the program

# %% [markdown]
# ## Try / Except
# In the last example, we figured out that there was a runtime error when the `val==4`.  What if we wanted to continue running our program even if that happens? We can use Try/Except to catch errors, and tell Python to do something else when they happen, instead of exiting the program.

# %% [markdown]
# ### Try / Except Block

# %%
try:
    # Tries to do this code
    pass
except:
    # If there is an error, keep going and do this instead
    pass

# %% [markdown]
# ### Here is  an example using 'try` / `except`
# #### We want to get an ID number from the participant

# %%
participant_id = input("Please type your participant ID number: ")

print('Your Participant ID number is: ', participant_id)
# Out:
# Please type your participant ID number: sdfadrgq34tgq43qwa
# Your Participant ID number is:  sdfadrgq34tgq43qwa

# %%
try:
    participant_id = input('Please type your Participant ID number: ') # participant_id is a string
    int(participant_id) # try to convert the participant_id into an integer.  It will crash if any of the character(s) in the string are not integers.
    print('Your Participant ID number is: ', participant_id)
except:
    print("That's not a valid Participant ID number")
# Out:
# Please type your Participant ID number: 2.0
# That's not a valid Participant ID number

# %% [markdown]
# #### Try / Except within a While Loop

# %%
ask_for_num = True
while ask_for_num:
    try:
        participant_id = input('Please type your Participant ID number: ') # participant_id is a string
        int(participant_id) # try to convert the participant_id into an integer.  It will crash if any of the character(s) in the string are not integers.
        ask_for_num = False
    except ValueError:
        print("Oops!  That was not valid participant ID number. Try again!")
        
print('Your Participant ID number is: ', participant_id)
# Out:
# Please type your Participant ID number: asdf
# Oops!  That was not valid participant ID number. Try again!
# Please type your Participant ID number: asdf
# Oops!  That was not valid participant ID number. Try again!
# Please type your Participant ID number: 23423
# Your Participant ID number is:  23423

# %% [markdown]
# ### More Try / Except

# %%
def divide(num1, num2):
    return num1 / num2

def safe_divide(num1, num2):
    
    try:
        output = num1 / num2
    except ZeroDivisionError:
        output = None
    
    return output

# %%
print(divide(2, 0))

# %%
print(safe_divide(2, 0))
# Out:
# None

# %% [markdown]
# ## Raising Errors

# %% [markdown]
# <div class="alert alert-success">
# You can also write code to raise an Exception if something unexpected happens. This won't fix anything, but it lets you send yourself a message, like displaying the contents of a variable, displaying the count in a loop, or whatever you need to help `step through` the problem.
# </div>

# %% [markdown]
# ### Raise Exception Examples

# %%
my_int = input('An integer please: ')
if not my_int.isnumeric():
    raise ValueError('I wanted a number! :(')
    
print('My integer is: ', my_int)
# Out:
# An integer please: k
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-bc64f24647db> in <module>
#       1 my_int = input('An integer please: ')
#       2 if not my_int.isnumeric():
# ----> 3     raise ValueError('I wanted a number! :(')
#       4
#       5 print('My integer is: ', my_int)
#
# ValueError: I wanted a number! :(

# %% [markdown]
# ## Runtime Errors
#
# - Runtime errors are produced by the runtime system if something goes wrong
# while the program is running.
# - Most runtime error messages include information about where the error occurred and what functions were
# executing.
# - A divide by zero error is a runtime error.

# %% [markdown]
# ### Example:
# - Recursion is a function defined by itself
# - Infinite recursion is when a recursive function calls itself again and again, going deeper and deeper, an infinite number of times.
# - An infinite recursion eventually causes a runtime error of maximum recursion depth exceeded.
#     - `RecursionError: maximum recursion depth exceeded`

# %%
def recurseInfinitely(n):
    recurseInfinitely(n+1)

recurseInfinitely(0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-762b3d4c7464> in <module>()
#       2     recurseInfinitely(n+1)
#       3
# ----> 4 recurseInfinitely(0)
#
# <ipython-input-19-762b3d4c7464> in recurseInfinitely(n)
#       1 def recurseInfinitely(n):
# ----> 2     recurseInfinitely(n+1)
#       3
#       4 recurseInfinitely(0)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-19-762b3d4c7464> in recurseInfinitely(n)
#       1 def recurseInfinitely(n):
# ----> 2     recurseInfinitely(n+1)
#       3
#       4 recurseInfinitely(0)
#
# RuntimeError: maximum recursion depth exceeded

# %% [markdown]
# ### Example - Infinite Looop
# An infinite loop is a loop that goes on forever.  Your program will hang and it won't give any error messages.  You'll have to interrupt it with they stop button in Jupyter Notebooks, or ctrl + c if you're running a python program from the command line.

# %%
x = 1
y = -1
while x > 0 and y < 0:
    x += 3
    y -= 4

# %% [markdown]
# To figure out this is happening, you can always print out the values of x and y in the loop and see if x ever gets to be <= 0 or if y ever gets >= 0

# %%
x = 1
y = -1
while x > 0 and y < 0:
    x += 3
    print("x: ", x)
    y -= 4
    print("y: ", y)
# Out:
# ('x: ', 4)
# ('y: ', -5)
# ('x: ', 7)
# ('y: ', -9)
# ('x: ', 10)
# ('y: ', -13)
# ('x: ', 13)
# ('y: ', -17)
# ('x: ', 16)
# ('y: ', -21)
# ('x: ', 19)
# ('y: ', -25)
# ('x: ', 22)
# ('y: ', -29)
# ('x: ', 25)
# ('y: ', -33)
# ('x: ', 28)
# ('y: ', -37)
# ('x: ', 31)
# ('y: ', -41)
# ('x: ', 34)
# ('y: ', -45)
# ('x: ', 37)
# ('y: ', -49)
# ('x: ', 40)
# ('y: ', -53)
# ('x: ', 43)
# ('y: ', -57)
# ('x: ', 46)
# ('y: ', -61)
# ('x: ', 49)
# ('y: ', -65)
# ('x: ', 52)
# ('y: ', -69)
# ('x: ', 55)
# ('y: ', -73)
# ('x: ', 58)
# ('y: ', -77)
# ('x: ', 61)
# ('y: ', -81)
# ('x: ', 64)
# ('y: ', -85)
# ('x: ', 67)
# ('y: ', -89)
# ('x: ', 70)
# ('y: ', -93)
# ('x: ', 73)
# ('y: ', -97)
# ('x: ', 76)
# ('y: ', -101)
# ('x: ', 79)
# ('y: ', -105)
# ('x: ', 82)
# ('y: ', -109)
# ('x: ', 85)
# ('y: ', -113)
# ('x: ', 88)
# ('y: ', -117)
# ('x: ', 91)
# ('y: ', -121)
# ('x: ', 94)
# ('y: ', -125)
# ('x: ', 97)
# ('y: ', -129)
# ('x: ', 100)
# ('y: ', -133)
# ('x: ', 103)
# ('y: ', -137)
# ('x: ', 106)
# ('y: ', -141)
# ('x: ', 109)
# ('y: ', -145)
# ('x: ', 112)
# ('y: ', -149)
# ('x: ', 115)
# ('y: ', -153)
# ('x: ', 118)
# ('y: ', -157)
# ('x: ', 121)
# ('y: ', -161)
# ('x: ', 124)
# ('y: ', -165)
# ('x: ', 127)
# ('y: ', -169)
# ('x: ', 130)
# ('y: ', -173)
# ('x: ', 133)
# ('y: ', -177)
# ('x: ', 136)
# ('y: ', -181)
# ('x: ', 139)
# ('y: ', -185)
# ('x: ', 142)
# ('y: ', -189)
# ('x: ', 145)
# ('y: ', -193)
# ('x: ', 148)
# ('y: ', -197)
# ('x: ', 151)
# ('y: ', -201)
# ('x: ', 154)
# ('y: ', -205)
# ('x: ', 157)
# ('y: ', -209)
# ('x: ', 160)
# ('y: ', -213)
# ('x: ', 163)
# ('y: ', -217)
# ('x: ', 166)
# ('y: ', -221)
# ('x: ', 169)
# ('y: ', -225)
# ('x: ', 172)
# ('y: ', -229)
# ('x: ', 175)
# ('y: ', -233)
# ('x: ', 178)
# ('y: ', -237)
# ('x: ', 181)
# ('y: ', -241)
# ('x: ', 184)
# ('y: ', -245)
# ('x: ', 187)
# ('y: ', -249)
# ('x: ', 190)
# ('y: ', -253)
# ('x: ', 193)
# ('y: ', -257)
# ('x: ', 196)
# ('y: ', -261)
# ('x: ', 199)
# ('y: ', -265)
# ('x: ', 202)
# ('y: ', -269)
# ('x: ', 205)
# ('y: ', -273)
# ('x: ', 208)
# ('y: ', -277)
# ('x: ', 211)
# ('y: ', -281)
# ('x: ', 214)
# ('y: ', -285)
# ('x: ', 217)
# ('y: ', -289)
# ('x: ', 220)
# ('y: ', -293)
# ('x: ', 223)
# ('y: ', -297)
# ('x: ', 226)
# ('y: ', -301)
# ('x: ', 229)
# ('y: ', -305)
# ('x: ', 232)
# ('y: ', -309)
# ('x: ', 235)
# ('y: ', -313)
# ('x: ', 238)
# ('y: ', -317)
# ('x: ', 241)
# ('y: ', -321)
# ('x: ', 244)
# ('y: ', -325)
# ('x: ', 247)
# ('y: ', -329)
# ('x: ', 250)
# ('y: ', -333)
# ('x: ', 253)
# ('y: ', -337)
# ('x: ', 256)
# ('y: ', -341)
# ('x: ', 259)
# ('y: ', -345)
# ('x: ', 262)
# ('y: ', -349)
# ('x: ', 265)
# ('y: ', -353)
# ('x: ', 268)
# ('y: ', -357)
# ('x: ', 271)
# ('y: ', -361)
# ('x: ', 274)
# ('y: ', -365)
# ('x: ', 277)
# ('y: ', -369)
# ('x: ', 280)
# ('y: ', -373)
# ('x: ', 283)
# ('y: ', -377)
# ('x: ', 286)
# ('y: ', -381)
# ('x: ', 289)
# ('y: ', -385)
# ('x: ', 292)
# ('y: ', -389)
# ('x: ', 295)
# ('y: ', -393)
# ('x: ', 298)
# ('y: ', -397)
# ('x: ', 301)
# ('y: ', -401)
# ('x: ', 304)
# ('y: ', -405)
# ('x: ', 307)
# ('y: ', -409)
# ('x: ', 310)
# ('y: ', -413)
# ('x: ', 313)
# ('y: ', -417)
# ('x: ', 316)
# ('y: ', -421)
# ('x: ', 319)
# ('y: ', -425)
# ('x: ', 322)
# ('y: ', -429)
# ('x: ', 325)
# ('y: ', -433)
# ('x: ', 328)
# ('y: ', -437)
# ('x: ', 331)
# ('y: ', -441)
# ('x: ', 334)
# ('y: ', -445)
# ('x: ', 337)
# ('y: ', -449)
# ('x: ', 340)
# ('y: ', -453)
# ('x: ', 343)
# ('y: ', -457)
# ('x: ', 346)
# ('y: ', -461)
# ('x: ', 349)
# ('y: ', -465)
# ('x: ', 352)
# ('y: ', -469)
# ('x: ', 355)
# ('y: ', -473)
# ('x: ', 358)
# ('y: ', -477)
# ('x: ', 361)
# ('y: ', -481)
# ('x: ', 364)
# ('y: ', -485)
# ('x: ', 367)
# ('y: ', -489)
# ('x: ', 370)
# ('y: ', -493)
# ('x: ', 373)
# ('y: ', -497)
# ('x: ', 376)
# ('y: ', -501)
# ('x: ', 379)
# ('y: ', -505)
# ('x: ', 382)
# ('y: ', -509)
# ('x: ', 385)
# ('y: ', -513)
# ('x: ', 388)
# ('y: ', -517)
# ('x: ', 391)
# ('y: ', -521)
# ('x: ', 394)
# ('y: ', -525)
# ('x: ', 397)
# ('y: ', -529)
# ('x: ', 400)
# ('y: ', -533)
# ('x: ', 403)
# ('y: ', -537)
# ('x: ', 406)
# ('y: ', -541)
# ('x: ', 409)
# ('y: ', -545)
# ('x: ', 412)
# ('y: ', -549)
# ('x: ', 415)
# ('y: ', -553)
# ('x: ', 418)
# ('y: ', -557)
# ('x: ', 421)
# ('y: ', -561)
# ('x: ', 424)
# ('y: ', -565)
# ('x: ', 427)
# ('y: ', -569)
# ('x: ', 430)
# ('y: ', -573)
# ('x: ', 433)
# ('y: ', -577)
# ('x: ', 436)
# ('y: ', -581)
# ('x: ', 439)
# ('y: ', -585)
# ('x: ', 442)
# ('y: ', -589)
# ('x: ', 445)
# ('y: ', -593)
# ('x: ', 448)
# ('y: ', -597)
# ('x: ', 451)
# ('y: ', -601)
# ('x: ', 454)
# ('y: ', -605)
# ('x: ', 457)
# ('y: ', -609)
# ('x: ', 460)
# ('y: ', -613)
# ('x: ', 463)
# ('y: ', -617)
# ('x: ', 466)
# ('y: ', -621)
# ('x: ', 469)
# ('y: ', -625)
# ('x: ', 472)
# ('y: ', -629)
# ('x: ', 475)
# ('y: ', -633)
# ('x: ', 478)
# ('y: ', -637)
# ('x: ', 481)
# ('y: ', -641)
# ('x: ', 484)
# ('y: ', -645)
# ('x: ', 487)
# ('y: ', -649)
# ('x: ', 490)
# ('y: ', -653)
# ('x: ', 493)
# ('y: ', -657)
# ('x: ', 496)
# ('y: ', -661)
# ('x: ', 499)
# ('y: ', -665)
# ('x: ', 502)
# ('y: ', -669)
# ('x: ', 505)
# ('y: ', -673)
# ('x: ', 508)
# ('y: ', -677)
# ('x: ', 511)
# ('y: ', -681)
# ('x: ', 514)
# ('y: ', -685)
# ('x: ', 517)
# ('y: ', -689)
# ('x: ', 520)
# ('y: ', -693)
# ('x: ', 523)
# ('y: ', -697)
# ('x: ', 526)
# ('y: ', -701)
# ('x: ', 529)
# ('y: ', -705)
# ('x: ', 532)
# ('y: ', -709)
# ('x: ', 535)
# ('y: ', -713)
# ('x: ', 538)
# ('y: ', -717)
# ('x: ', 541)
# ('y: ', -721)
# ('x: ', 544)
# ('y: ', -725)
# ('x: ', 547)
# ('y: ', -729)
# ('x: ', 550)
# ('y: ', -733)
# ('x: ', 553)
# ('y: ', -737)
# ('x: ', 556)
# ('y: ', -741)
# ('x: ', 559)
# ('y: ', -745)
# ('x: ', 562)
# ('y: ', -749)
# ('x: ', 565)
# ('y: ', -753)
# ('x: ', 568)
# ('y: ', -757)
# ('x: ', 571)
# ('y: ', -761)
# ('x: ', 574)
# ('y: ', -765)
# ('x: ', 577)
# ('y: ', -769)
# ('x: ', 580)
# ('y: ', -773)
# ('x: ', 583)
# ('y: ', -777)
# ('x: ', 586)
# ('y: ', -781)
# ('x: ', 589)
# ('y: ', -785)
# ('x: ', 592)
# ('y: ', -789)
# ('x: ', 595)
# ('y: ', -793)
# ('x: ', 598)
# ('y: ', -797)
# ('x: ', 601)
# ('y: ', -801)
# ('x: ', 604)
# ('y: ', -805)
# ('x: ', 607)
# ('y: ', -809)
# ('x: ', 610)
# ('y: ', -813)
# ('x: ', 613)
# ('y: ', -817)
# ('x: ', 616)
# ('y: ', -821)
# ('x: ', 619)
# ('y: ', -825)
# ('x: ', 622)
# ('y: ', -829)
# ('x: ', 625)
# ('y: ', -833)
# ('x: ', 628)
# ('y: ', -837)
# ('x: ', 631)
# ('y: ', -841)
# ('x: ', 634)
# ('y: ', -845)
# ('x: ', 637)
# ('y: ', -849)
# ('x: ', 640)
# ('y: ', -853)
# ('x: ', 643)
# ('y: ', -857)
# ('x: ', 646)
# ('y: ', -861)
# ('x: ', 649)
# ('y: ', -865)
# ('x: ', 652)
# ('y: ', -869)
# ('x: ', 655)
# ('y: ', -873)
# ('x: ', 658)
# ('y: ', -877)
# ('x: ', 661)
# ('y: ', -881)
# ('x: ', 664)
# ('y: ', -885)
# ('x: ', 667)
# ('y: ', -889)
# ('x: ', 670)
# ('y: ', -893)
# ('x: ', 673)
# ('y: ', -897)
# ('x: ', 676)
# ('y: ', -901)
# ('x: ', 679)
# ('y: ', -905)
# ('x: ', 682)
# ('y: ', -909)
# ('x: ', 685)
# ('y: ', -913)
# ('x: ', 688)
# ('y: ', -917)
# ('x: ', 691)
# ('y: ', -921)
# ('x: ', 694)
# ('y: ', -925)
# ('x: ', 697)
# ('y: ', -929)
# ('x: ', 700)
# ('y: ', -933)
# ('x: ', 703)
# ('y: ', -937)
# ('x: ', 706)
# ('y: ', -941)
# ('x: ', 709)
# ('y: ', -945)
# ('x: ', 712)
# ('y: ', -949)
# ('x: ', 715)
# ('y: ', -953)
# ('x: ', 718)
# ('y: ', -957)
# ('x: ', 721)
# ('y: ', -961)
# ('x: ', 724)
# ('y: ', -965)
# ('x: ', 727)
# ('y: ', -969)
# ('x: ', 730)
# ('y: ', -973)
# ('x: ', 733)
# ('y: ', -977)
# ('x: ', 736)
# ('y: ', -981)
# ('x: ', 739)
# ('y: ', -985)
# ('x: ', 742)
# ('y: ', -989)
# ('x: ', 745)
# ('y: ', -993)
# ('x: ', 748)
# ('y: ', -997)
# ('x: ', 751)
# ('y: ', -1001)
# ('x: ', 754)
# ('y: ', -1005)
# ('x: ', 757)
# ('y: ', -1009)
# ('x: ', 760)
# ('y: ', -1013)
# ('x: ', 763)
# ('y: ', -1017)
# ('x: ', 766)
# ('y: ', -1021)
# ('x: ', 769)
# ('y: ', -1025)
# ('x: ', 772)
# ('y: ', -1029)
# ('x: ', 775)
# ('y: ', -1033)
# ('x: ', 778)
# ('y: ', -1037)
# ('x: ', 781)
# ('y: ', -1041)
# ('x: ', 784)
# ('y: ', -1045)
# ('x: ', 787)
# ('y: ', -1049)
# ('x: ', 790)
# ('y: ', -1053)
# ('x: ', 793)
# ('y: ', -1057)
# ('x: ', 796)
# ('y: ', -1061)
# ('x: ', 799)
# ('y: ', -1065)
# ('x: ', 802)
# ('y: ', -1069)
# ('x: ', 805)
# ('y: ', -1073)
# ('x: ', 808)
# ('y: ', -1077)
# ('x: ', 811)
# ('y: ', -1081)
# ('x: ', 814)
# ('y: ', -1085)
# ('x: ', 817)
# ('y: ', -1089)
# ('x: ', 820)
# ('y: ', -1093)
# ('x: ', 823)
# ('y: ', -1097)
# ('x: ', 826)
# ('y: ', -1101)
# ('x: ', 829)
# ('y: ', -1105)
# ('x: ', 832)
# ('y: ', -1109)
# ('x: ', 835)
# ('y: ', -1113)
# ('x: ', 838)
# ('y: ', -1117)
# ('x: ', 841)
# ('y: ', -1121)
# ('x: ', 844)
# ('y: ', -1125)
# ('x: ', 847)
# ('y: ', -1129)
# ('x: ', 850)
# ('y: ', -1133)
# ('x: ', 853)
# ('y: ', -1137)
# ('x: ', 856)
# ('y: ', -1141)
# ('x: ', 859)
# ('y: ', -1145)
# ('x: ', 862)
# ('y: ', -1149)
# ('x: ', 865)
# ('y: ', -1153)
# ('x: ', 868)
# ('y: ', -1157)
# ('x: ', 871)
# ('y: ', -1161)
# ('x: ', 874)
# ('y: ', -1165)
# ('x: ', 877)
# ('y: ', -1169)
# ('x: ', 880)
# ('y: ', -1173)
# ('x: ', 883)
# ('y: ', -1177)
# ('x: ', 886)
# ('y: ', -1181)
# ('x: ', 889)
# ('y: ', -1185)
# ('x: ', 892)
# ('y: ', -1189)
# ('x: ', 895)
# ('y: ', -1193)
# ('x: ', 898)
# ('y: ', -1197)
# ('x: ', 901)
# ('y: ', -1201)
# ('x: ', 904)
# ('y: ', -1205)
# ('x: ', 907)
# ('y: ', -1209)
# ('x: ', 910)
# ('y: ', -1213)
# ('x: ', 913)
# ('y: ', -1217)
# ('x: ', 916)
# ('y: ', -1221)
# ('x: ', 919)
# ('y: ', -1225)
# ('x: ', 922)
# ('y: ', -1229)
# ('x: ', 925)
# ('y: ', -1233)
# ('x: ', 928)
# ('y: ', -1237)
# ('x: ', 931)
# ('y: ', -1241)
# ('x: ', 934)
# ('y: ', -1245)
# ('x: ', 937)
# ('y: ', -1249)
# ('x: ', 940)
# ('y: ', -1253)
# ('x: ', 943)
# ('y: ', -1257)
# ('x: ', 946)
# ('y: ', -1261)
# ('x: ', 949)
# ('y: ', -1265)
# ('x: ', 952)
# ('y: ', -1269)
# ('x: ', 955)
# ('y: ', -1273)
# ('x: ', 958)
# ('y: ', -1277)
# ('x: ', 961)
# ('y: ', -1281)
# ('x: ', 964)
# ('y: ', -1285)
# ('x: ', 967)
# ('y: ', -1289)
# ('x: ', 970)
# ('y: ', -1293)
# ('x: ', 973)
# ('y: ', -1297)
# ('x: ', 976)
# ('y: ', -1301)
# ('x: ', 979)
# ('y: ', -1305)
# ('x: ', 982)
# ('y: ', -1309)
# ('x: ', 985)
# ('y: ', -1313)
# ('x: ', 988)
# ('y: ', -1317)
# ('x: ', 991)
# ('y: ', -1321)
# ('x: ', 994)
# ('y: ', -1325)
# ('x: ', 997)
# ('y: ', -1329)
# ('x: ', 1000)
# ('y: ', -1333)
# ('x: ', 1003)
# ('y: ', -1337)
# ('x: ', 1006)
# ('y: ', -1341)
# ('x: ', 1009)
# ('y: ', -1345)
# ('x: ', 1012)
# ('y: ', -1349)
# ('x: ', 1015)
# ('y: ', -1353)
# ('x: ', 1018)
# ('y: ', -1357)
# ('x: ', 1021)
# ('y: ', -1361)
# ('x: ', 1024)
# ('y: ', -1365)
# ('x: ', 1027)
# ('y: ', -1369)
# ('x: ', 1030)
# ('y: ', -1373)
# ('x: ', 1033)
# ('y: ', -1377)
# ('x: ', 1036)
# ('y: ', -1381)
# ('x: ', 1039)
# ('y: ', -1385)
# ('x: ', 1042)
# ('y: ', -1389)
# ('x: ', 1045)
# ('y: ', -1393)
# ('x: ', 1048)
# ('y: ', -1397)
# ('x: ', 1051)
# ('y: ', -1401)
# ('x: ', 1054)
# ('y: ', -1405)
# ('x: ', 1057)
# ('y: ', -1409)
# ('x: ', 1060)
# ('y: ', -1413)
# ('x: ', 1063)
# ('y: ', -1417)
# ('x: ', 1066)
# ('y: ', -1421)
# ('x: ', 1069)
# ('y: ', -1425)
# ('x: ', 1072)
# ('y: ', -1429)
# ('x: ', 1075)
# ('y: ', -1433)
# ('x: ', 1078)
# ('y: ', -1437)
# ('x: ', 1081)
# ('y: ', -1441)
# ('x: ', 1084)
# ('y: ', -1445)
# ('x: ', 1087)
# ('y: ', -1449)
# ('x: ', 1090)
# ('y: ', -1453)
# ('x: ', 1093)
# ('y: ', -1457)
# ('x: ', 1096)
# ('y: ', -1461)
# ('x: ', 1099)
# ('y: ', -1465)
# ('x: ', 1102)
# ('y: ', -1469)
# ('x: ', 1105)
# ('y: ', -1473)
# ('x: ', 1108)
# ('y: ', -1477)
# ('x: ', 1111)
# ('y: ', -1481)
# ('x: ', 1114)
# ('y: ', -1485)
# ('x: ', 1117)
# ('y: ', -1489)
# ('x: ', 1120)
# ('y: ', -1493)
# ('x: ', 1123)
# ('y: ', -1497)
# ('x: ', 1126)
# ('y: ', -1501)
# ('x: ', 1129)
# ('y: ', -1505)
# ('x: ', 1132)
# ('y: ', -1509)
# ('x: ', 1135)
# ('y: ', -1513)
# ('x: ', 1138)
# ('y: ', -1517)
# ('x: ', 1141)
# ('y: ', -1521)
# ('x: ', 1144)
# ('y: ', -1525)
# ('x: ', 1147)
# ('y: ', -1529)
# ('x: ', 1150)
# ('y: ', -1533)
# ('x: ', 1153)
# ('y: ', -1537)
# ('x: ', 1156)
# ('y: ', -1541)
# ('x: ', 1159)
# ('y: ', -1545)
# ('x: ', 1162)
# ('y: ', -1549)
# ('x: ', 1165)
# ('y: ', -1553)
# ('x: ', 1168)
# ('y: ', -1557)
# ('x: ', 1171)
# ('y: ', -1561)
# ('x: ', 1174)
# ('y: ', -1565)
# ('x: ', 1177)
# ('y: ', -1569)
# ('x: ', 1180)
# ('y: ', -1573)
# ('x: ', 1183)
# ('y: ', -1577)
# ('x: ', 1186)
# ('y: ', -1581)
# ('x: ', 1189)
# ('y: ', -1585)
# ('x: ', 1192)
# ('y: ', -1589)
# ('x: ', 1195)
# ('y: ', -1593)
# ('x: ', 1198)
# ('y: ', -1597)
# ('x: ', 1201)
# ('y: ', -1601)
# ('x: ', 1204)
# ('y: ', -1605)
# ('x: ', 1207)
# ('y: ', -1609)
# ('x: ', 1210)
# ('y: ', -1613)
# ('x: ', 1213)
# ('y: ', -1617)
# ('x: ', 1216)
# ('y: ', -1621)
# ('x: ', 1219)
# ('y: ', -1625)
# ('x: ', 1222)
# ('y: ', -1629)
# ('x: ', 1225)
# ('y: ', -1633)
# ('x: ', 1228)
# ('y: ', -1637)
# ('x: ', 1231)
# ('y: ', -1641)
# ('x: ', 1234)
# ('y: ', -1645)
# ('x: ', 1237)
# ('y: ', -1649)
# ('x: ', 1240)
# ('y: ', -1653)
# ('x: ', 1243)
# ('y: ', -1657)
# ('x: ', 1246)
# ('y: ', -1661)
# ('x: ', 1249)
# ('y: ', -1665)
# ('x: ', 1252)
# ('y: ', -1669)
# ('x: ', 1255)
# ('y: ', -1673)
# ('x: ', 1258)
# ('y: ', -1677)
# ('x: ', 1261)
# ('y: ', -1681)
# ('x: ', 1264)
# ('y: ', -1685)
# ('x: ', 1267)
# ('y: ', -1689)
# ('x: ', 1270)
# ('y: ', -1693)
# ('x: ', 1273)
# ('y: ', -1697)
# ('x: ', 1276)
# ('y: ', -1701)
# ('x: ', 1279)
# ('y: ', -1705)
# ('x: ', 1282)
# ('y: ', -1709)
# ('x: ', 1285)
# ('y: ', -1713)
# ('x: ', 1288)
# ('y: ', -1717)
# ('x: ', 1291)
# ('y: ', -1721)
# ('x: ', 1294)
# ('y: ', -1725)
# ('x: ', 1297)
# ('y: ', -1729)
# ('x: ', 1300)
# ('y: ', -1733)
# ('x: ', 1303)
# ('y: ', -1737)
# ('x: ', 1306)
# ('y: ', -1741)
# ('x: ', 1309)
# ('y: ', -1745)
# ('x: ', 1312)
# ('y: ', -1749)
# ('x: ', 1315)
# ('y: ', -1753)
# ('x: ', 1318)
# ('y: ', -1757)
# ('x: ', 1321)
# ('y: ', -1761)
# ('x: ', 1324)
# ('y: ', -1765)
# ('x: ', 1327)
# ('y: ', -1769)
# ('x: ', 1330)
# ('y: ', -1773)
# ('x: ', 1333)
# ('y: ', -1777)
# ('x: ', 1336)
# ('y: ', -1781)
# ('x: ', 1339)
# ('y: ', -1785)
# ('x: ', 1342)
# ('y: ', -1789)
# ('x: ', 1345)
# ('y: ', -1793)
# ('x: ', 1348)
# ('y: ', -1797)
# ('x: ', 1351)
# ('y: ', -1801)
# ('x: ', 1354)
# ('y: ', -1805)
# ('x: ', 1357)
# ('y: ', -1809)
# ('x: ', 1360)
# ('y: ', -1813)
# ('x: ', 1363)
# ('y: ', -1817)
# ('x: ', 1366)
# ('y: ', -1821)
# ('x: ', 1369)
# ('y: ', -1825)
# ('x: ', 1372)
# ('y: ', -1829)
# ('x: ', 1375)
# ('y: ', -1833)
# ('x: ', 1378)
# ('y: ', -1837)
# ('x: ', 1381)
# ('y: ', -1841)
# ('x: ', 1384)
# ('y: ', -1845)
# ('x: ', 1387)
# ('y: ', -1849)
# ('x: ', 1390)
# ('y: ', -1853)
# ('x: ', 1393)
# ('y: ', -1857)
# ('x: ', 1396)
# ('y: ', -1861)
# ('x: ', 1399)
# ('y: ', -1865)
# ('x: ', 1402)
# ('y: ', -1869)
# ('x: ', 1405)
# ('y: ', -1873)
# ('x: ', 1408)
# ('y: ', -1877)
# ('x: ', 1411)
# ('y: ', -1881)
# ('x: ', 1414)
# ('y: ', -1885)
# ('x: ', 1417)
# ('y: ', -1889)
# ('x: ', 1420)
# ('y: ', -1893)
# ('x: ', 1423)
# ('y: ', -1897)
# ('x: ', 1426)
# ('y: ', -1901)
# ('x: ', 1429)
# ('y: ', -1905)
# ('x: ', 1432)
# ('y: ', -1909)
# ('x: ', 1435)
# ('y: ', -1913)
# ('x: ', 1438)
# ('y: ', -1917)
# ('x: ', 1441)
# ('y: ', -1921)
# ('x: ', 1444)
# ('y: ', -1925)
# ('x: ', 1447)
# ('y: ', -1929)
# ('x: ', 1450)
# ('y: ', -1933)
# ('x: ', 1453)
# ('y: ', -1937)
# ('x: ', 1456)
# ('y: ', -1941)
# ('x: ', 1459)
# ('y: ', -1945)
# ('x: ', 1462)
# ('y: ', -1949)
# ('x: ', 1465)
# ('y: ', -1953)
# ('x: ', 1468)
# ('y: ', -1957)
# ('x: ', 1471)
# ('y: ', -1961)
# ('x: ', 1474)
# ('y: ', -1965)
# ('x: ', 1477)
# ('y: ', -1969)
# ('x: ', 1480)
# ('y: ', -1973)
# ('x: ', 1483)
# ('y: ', -1977)
# ('x: ', 1486)
# ('y: ', -1981)
# ('x: ', 1489)
# ('y: ', -1985)
# ('x: ', 1492)
# ('y: ', -1989)
# ('x: ', 1495)
# ('y: ', -1993)
# ('x: ', 1498)
# ('y: ', -1997)
# ('x: ', 1501)
# ('y: ', -2001)
# ('x: ', 1504)
# ('y: ', -2005)
# ('x: ', 1507)
# ('y: ', -2009)
# ('x: ', 1510)
# ('y: ', -2013)
# ('x: ', 1513)
# ('y: ', -2017)
# ('x: ', 1516)
# ('y: ', -2021)
# ('x: ', 1519)
# ('y: ', -2025)
# ('x: ', 1522)
# ('y: ', -2029)
# ('x: ', 1525)
# ('y: ', -2033)
# ('x: ', 1528)
# ('y: ', -2037)
# ('x: ', 1531)
# ('y: ', -2041)
# ('x: ', 1534)
# ('y: ', -2045)
# ('x: ', 1537)
# ('y: ', -2049)
# ('x: ', 1540)
# ('y: ', -2053)
# ('x: ', 1543)
# ('y: ', -2057)
# ('x: ', 1546)
# ('y: ', -2061)
# ('x: ', 1549)
# ('y: ', -2065)
# ('x: ', 1552)
# ('y: ', -2069)
# ('x: ', 1555)
# ('y: ', -2073)
# ('x: ', 1558)
# ('y: ', -2077)
# ('x: ', 1561)
# ('y: ', -2081)
# ('x: ', 1564)
# ('y: ', -2085)
# ('x: ', 1567)
# ('y: ', -2089)
# ('x: ', 1570)
# ('y: ', -2093)
# ('x: ', 1573)
# ('y: ', -2097)
# ('x: ', 1576)
# ('y: ', -2101)
# ('x: ', 1579)
# ('y: ', -2105)
# ('x: ', 1582)
# ('y: ', -2109)
# ('x: ', 1585)
# ('y: ', -2113)
# ('x: ', 1588)
# ('y: ', -2117)
# ('x: ', 1591)
# ('y: ', -2121)
# ('x: ', 1594)
# ('y: ', -2125)
# ('x: ', 1597)
# ('y: ', -2129)
# ('x: ', 1600)
# ('y: ', -2133)
# ('x: ', 1603)
# ('y: ', -2137)
# ('x: ', 1606)
# ('y: ', -2141)
# ('x: ', 1609)
# ('y: ', -2145)
# ('x: ', 1612)
# ('y: ', -2149)
# ('x: ', 1615)
# ('y: ', -2153)
# ('x: ', 1618)
# ('y: ', -2157)
# ('x: ', 1621)
# ('y: ', -2161)
# ('x: ', 1624)
# ('y: ', -2165)
# ('x: ', 1627)
# ('y: ', -2169)
# ('x: ', 1630)
# ('y: ', -2173)
# ('x: ', 1633)
# ('y: ', -2177)
# ('x: ', 1636)
# ('y: ', -2181)
# ('x: ', 1639)
# ('y: ', -2185)
# ('x: ', 1642)
# ('y: ', -2189)
# ('x: ', 1645)
# ('y: ', -2193)
# ('x: ', 1648)
# ('y: ', -2197)
# ('x: ', 1651)
# ('y: ', -2201)
# ('x: ', 1654)
# ('y: ', -2205)
# ('x: ', 1657)
# ('y: ', -2209)
# ('x: ', 1660)
# ('y: ', -2213)
# ('x: ', 1663)
# ('y: ', -2217)
# ('x: ', 1666)
# ('y: ', -2221)
# ('x: ', 1669)
# ('y: ', -2225)
# ('x: ', 1672)
# ('y: ', -2229)
# ('x: ', 1675)
# ('y: ', -2233)
# ('x: ', 1678)
# ('y: ', -2237)
# ('x: ', 1681)
# ('y: ', -2241)
# ('x: ', 1684)
# ('y: ', -2245)
# ('x: ', 1687)
# ('y: ', -2249)
# ('x: ', 1690)
# ('y: ', -2253)
# ('x: ', 1693)
# ('y: ', -2257)
# ('x: ', 1696)
# ('y: ', -2261)
# ('x: ', 1699)
# ('y: ', -2265)
# ('x: ', 1702)
# ('y: ', -2269)
# ('x: ', 1705)
# ('y: ', -2273)
# ('x: ', 1708)
# ('y: ', -2277)
# ('x: ', 1711)
# ('y: ', -2281)
# ('x: ', 1714)
# ('y: ', -2285)
# ('x: ', 1717)
# ('y: ', -2289)
# ('x: ', 1720)
# ('y: ', -2293)
# ('x: ', 1723)
# ('y: ', -2297)
# ('x: ', 1726)
# ('y: ', -2301)
# ('x: ', 1729)
# ('y: ', -2305)
# ('x: ', 1732)
# ('y: ', -2309)
# ('x: ', 1735)
# ('y: ', -2313)
# ('x: ', 1738)
# ('y: ', -2317)
# ('x: ', 1741)
# ('y: ', -2321)
# ('x: ', 1744)
# ('y: ', -2325)
# ('x: ', 1747)
# ('y: ', -2329)
# ('x: ', 1750)
# ('y: ', -2333)
# ('x: ', 1753)
# ('y: ', -2337)
# ('x: ', 1756)
# ('y: ', -2341)
# ('x: ', 1759)
# ('y: ', -2345)
# ('x: ', 1762)
# ('y: ', -2349)
# ('x: ', 1765)
# ('y: ', -2353)
# ('x: ', 1768)
# ('y: ', -2357)
# ('x: ', 1771)
# ('y: ', -2361)
# ('x: ', 1774)
# ('y: ', -2365)
# ('x: ', 1777)
# ('y: ', -2369)
# ('x: ', 1780)
# ('y: ', -2373)
# ('x: ', 1783)
# ('y: ', -2377)
# ('x: ', 1786)
# ('y: ', -2381)
# ('x: ', 1789)
# ('y: ', -2385)
# ('x: ', 1792)
# ('y: ', -2389)
# ('x: ', 1795)
# ('y: ', -2393)
# ('x: ', 1798)
# ('y: ', -2397)
# ('x: ', 1801)
# ('y: ', -2401)
# ('x: ', 1804)
# ('y: ', -2405)
# ('x: ', 1807)
# ('y: ', -2409)
# ('x: ', 1810)
# ('y: ', -2413)
# ('x: ', 1813)
# ('y: ', -2417)
# ('x: ', 1816)
# ('y: ', -2421)
# ('x: ', 1819)
# ('y: ', -2425)
# ('x: ', 1822)
# ('y: ', -2429)
# ('x: ', 1825)
# ('y: ', -2433)
# ('x: ', 1828)
# ('y: ', -2437)
# ('x: ', 1831)
# ('y: ', -2441)
# ('x: ', 1834)
# ('y: ', -2445)
# ('x: ', 1837)
# ('y: ', -2449)
# ('x: ', 1840)
# ('y: ', -2453)
# ('x: ', 1843)
# ('y: ', -2457)
# ('x: ', 1846)
# ('y: ', -2461)
# ('x: ', 1849)
# ('y: ', -2465)
# ('x: ', 1852)
# ('y: ', -2469)
# ('x: ', 1855)
# ('y: ', -2473)
# ('x: ', 1858)
# ('y: ', -2477)
# ('x: ', 1861)
# ('y: ', -2481)
# ('x: ', 1864)
# ('y: ', -2485)
# ('x: ', 1867)
# ('y: ', -2489)
# ('x: ', 1870)
# ('y: ', -2493)
# ('x: ', 1873)
# ('y: ', -2497)
# ('x: ', 1876)
# ('y: ', -2501)
# ('x: ', 1879)
# ('y: ', -2505)
# ('x: ', 1882)
# ('y: ', -2509)
# ('x: ', 1885)
# ('y: ', -2513)
# ('x: ', 1888)
# ('y: ', -2517)
# ('x: ', 1891)
# ('y: ', -2521)
# ('x: ', 1894)
# ('y: ', -2525)
# ('x: ', 1897)
# ('y: ', -2529)
# ('x: ', 1900)
# ('y: ', -2533)
# ('x: ', 1903)
# ('y: ', -2537)
# ('x: ', 1906)
# ('y: ', -2541)
# ('x: ', 1909)
# ('y: ', -2545)
# ('x: ', 1912)
# ('y: ', -2549)
# ('x: ', 1915)
# ('y: ', -2553)
# ('x: ', 1918)
# ('y: ', -2557)
# ('x: ', 1921)
# ('y: ', -2561)
# ('x: ', 1924)
# ('y: ', -2565)
# ('x: ', 1927)
# ('y: ', -2569)
# ('x: ', 1930)
# ('y: ', -2573)
# ('x: ', 1933)
# ('y: ', -2577)
# ('x: ', 1936)
# ('y: ', -2581)
# ('x: ', 1939)
# ('y: ', -2585)
# ('x: ', 1942)
# ('y: ', -2589)
# ('x: ', 1945)
# ('y: ', -2593)
# ('x: ', 1948)
# ('y: ', -2597)
# ('x: ', 1951)
# ('y: ', -2601)
# ('x: ', 1954)
# ('y: ', -2605)
# ('x: ', 1957)
# ('y: ', -2609)
# ('x: ', 1960)
# ('y: ', -2613)
# ('x: ', 1963)
# ('y: ', -2617)
# ('x: ', 1966)
# ('y: ', -2621)
# ('x: ', 1969)
# ('y: ', -2625)
# ('x: ', 1972)
# ('y: ', -2629)
# ('x: ', 1975)
# ('y: ', -2633)
# ('x: ', 1978)
# ('y: ', -2637)
# ('x: ', 1981)
# ('y: ', -2641)
# ('x: ', 1984)
# ('y: ', -2645)
# ('x: ', 1987)
# ('y: ', -2649)
# ('x: ', 1990)
# ('y: ', -2653)
# ('x: ', 1993)
# ('y: ', -2657)
# ('x: ', 1996)
# ('y: ', -2661)
# ('x: ', 1999)
# ('y: ', -2665)
# ('x: ', 2002)
# ('y: ', -2669)
# ('x: ', 2005)
# ('y: ', -2673)
# ('x: ', 2008)
# ('y: ', -2677)
# ('x: ', 2011)
# ('y: ', -2681)
# ('x: ', 2014)
# ('y: ', -2685)
# ('x: ', 2017)
# ('y: ', -2689)
# ('x: ', 2020)
# ('y: ', -2693)
# ('x: ', 2023)
# ('y: ', -2697)
# ('x: ', 2026)
# ('y: ', -2701)
# ('x: ', 2029)
# ('y: ', -2705)
# ('x: ', 2032)
# ('y: ', -2709)
# ('x: ', 2035)
# ('y: ', -2713)
# ('x: ', 2038)
# ('y: ', -2717)
# ('x: ', 2041)
# ('y: ', -2721)
# ('x: ', 2044)
# ('y: ', -2725)
# ('x: ', 2047)
# ('y: ', -2729)
# ('x: ', 2050)
# ('y: ', -2733)
# ('x: ', 2053)
# ('y: ', -2737)
# ('x: ', 2056)
# ('y: ', -2741)
# ('x: ', 2059)
# ('y: ', -2745)
# ('x: ', 2062)
# ('y: ', -2749)
# ('x: ', 2065)
# ('y: ', -2753)
# ('x: ', 2068)
# ('y: ', -2757)
# ('x: ', 2071)
# ('y: ', -2761)
# ('x: ', 2074)
# ('y: ', -2765)
# ('x: ', 2077)
# ('y: ', -2769)
# ('x: ', 2080)
# ('y: ', -2773)
# ('x: ', 2083)
# ('y: ', -2777)
# ('x: ', 2086)
# ('y: ', -2781)
# ('x: ', 2089)
# ('y: ', -2785)
# ('x: ', 2092)
# ('y: ', -2789)
# ('x: ', 2095)
# ('y: ', -2793)
# ('x: ', 2098)
# ('y: ', -2797)
# ('x: ', 2101)
# ('y: ', -2801)
# ('x: ', 2104)
# ('y: ', -2805)
# ('x: ', 2107)
# ('y: ', -2809)
# ('x: ', 2110)
# ('y: ', -2813)
# ('x: ', 2113)
# ('y: ', -2817)
# ('x: ', 2116)
# ('y: ', -2821)
# ('x: ', 2119)
# ('y: ', -2825)
# ('x: ', 2122)
# ('y: ', -2829)
# ('x: ', 2125)
# ('y: ', -2833)
# ('x: ', 2128)
# ('y: ', -2837)
# ('x: ', 2131)
# ('y: ', -2841)
# ('x: ', 2134)
# ('y: ', -2845)
# ('x: ', 2137)
# ('y: ', -2849)
# ('x: ', 2140)
# ('y: ', -2853)
# ('x: ', 2143)
# ('y: ', -2857)
# ('x: ', 2146)
# ('y: ', -2861)
# ('x: ', 2149)
# ('y: ', -2865)
# ('x: ', 2152)
# ('y: ', -2869)
# ('x: ', 2155)
# ('y: ', -2873)
# ('x: ', 2158)
# ('y: ', -2877)
# ('x: ', 2161)
# ('y: ', -2881)
# ('x: ', 2164)
# ('y: ', -2885)
# ('x: ', 2167)
# ('y: ', -2889)
# ('x: ', 2170)
# ('y: ', -2893)
# ('x: ', 2173)
# ('y: ', -2897)
# ('x: ', 2176)
# ('y: ', -2901)
# ('x: ', 2179)
# ('y: ', -2905)
# ('x: ', 2182)
# ('y: ', -2909)
# ('x: ', 2185)
# ('y: ', -2913)
# ('x: ', 2188)
# ('y: ', -2917)
# ('x: ', 2191)
# ('y: ', -2921)
# ('x: ', 2194)
# ('y: ', -2925)
# ('x: ', 2197)
# ('y: ', -2929)
# ('x: ', 2200)
# ('y: ', -2933)
# ('x: ', 2203)
# ('y: ', -2937)
# ('x: ', 2206)
# ('y: ', -2941)
# ('x: ', 2209)
# ('y: ', -2945)
# ('x: ', 2212)
# ('y: ', -2949)
# ('x: ', 2215)
# ('y: ', -2953)
# ('x: ', 2218)
# ('y: ', -2957)
# ('x: ', 2221)
# ('y: ', -2961)
# ('x: ', 2224)
# ('y: ', -2965)
# ('x: ', 2227)
# ('y: ', -2969)
# ('x: ', 2230)
# ('y: ', -2973)
# ('x: ', 2233)
# ('y: ', -2977)
# ('x: ', 2236)
# ('y: ', -2981)
# ('x: ', 2239)
# ('y: ', -2985)
# ('x: ', 2242)
# ('y: ', -2989)
# ('x: ', 2245)
# ('y: ', -2993)
# ('x: ', 2248)
# ('y: ', -2997)
# ('x: ', 2251)
# ('y: ', -3001)
# ('x: ', 2254)
# ('y: ', -3005)
# ('x: ', 2257)
# ('y: ', -3009)
# ('x: ', 2260)
# ('y: ', -3013)
# ('x: ', 2263)
# ('y: ', -3017)
# ('x: ', 2266)
# ('y: ', -3021)
# ('x: ', 2269)
# ('y: ', -3025)
# ('x: ', 2272)
# ('y: ', -3029)
# ('x: ', 2275)
# ('y: ', -3033)
# ('x: ', 2278)
# ('y: ', -3037)
# ('x: ', 2281)
# ('y: ', -3041)
# ('x: ', 2284)
# ('y: ', -3045)
# ('x: ', 2287)
# ('y: ', -3049)
# ('x: ', 2290)
# ('y: ', -3053)
# ('x: ', 2293)
# ('y: ', -3057)
# ('x: ', 2296)
# ('y: ', -3061)
# ('x: ', 2299)
# ('y: ', -3065)
# ('x: ', 2302)
# ('y: ', -3069)
# ('x: ', 2305)
# ('y: ', -3073)
# ('x: ', 2308)
# ('y: ', -3077)
# ('x: ', 2311)
# ('y: ', -3081)
# ('x: ', 2314)
# ('y: ', -3085)
# ('x: ', 2317)
# ('y: ', -3089)
# ('x: ', 2320)
# ('y: ', -3093)
# ('x: ', 2323)
# ('y: ', -3097)
# ('x: ', 2326)
# ('y: ', -3101)
# ('x: ', 2329)
# ('y: ', -3105)
# ('x: ', 2332)
# ('y: ', -3109)
# ('x: ', 2335)
# ('y: ', -3113)
# ('x: ', 2338)
# ('y: ', -3117)
# ('x: ', 2341)
# ('y: ', -3121)
# ('x: ', 2344)
# ('y: ', -3125)
# ('x: ', 2347)
# ('y: ', -3129)
# ('x: ', 2350)
# ('y: ', -3133)
# ('x: ', 2353)
# ('y: ', -3137)
# ('x: ', 2356)
# ('y: ', -3141)
# ('x: ', 2359)
# ('y: ', -3145)
# ('x: ', 2362)
# ('y: ', -3149)
# ('x: ', 2365)
# ('y: ', -3153)
# ('x: ', 2368)
# ('y: ', -3157)
# ('x: ', 2371)
# ('y: ', -3161)
# ('x: ', 2374)
# ('y: ', -3165)
# ('x: ', 2377)
# ('y: ', -3169)
# ('x: ', 2380)
# ('y: ', -3173)
# ('x: ', 2383)
# ('y: ', -3177)
# ('x: ', 2386)
# ('y: ', -3181)
# ('x: ', 2389)
# ('y: ', -3185)
# ('x: ', 2392)
# ('y: ', -3189)
# ('x: ', 2395)
# ('y: ', -3193)
# ('x: ', 2398)
# ('y: ', -3197)
# ('x: ', 2401)
# ('y: ', -3201)
# ('x: ', 2404)
# ('y: ', -3205)
# ('x: ', 2407)
# ('y: ', -3209)
# ('x: ', 2410)
# ('y: ', -3213)
# ('x: ', 2413)
# ('y: ', -3217)
# ('x: ', 2416)
# ('y: ', -3221)
# ('x: ', 2419)
# ('y: ', -3225)
# ('x: ', 2422)
# ('y: ', -3229)
# ('x: ', 2425)
# ('y: ', -3233)
# ('x: ', 2428)
# ('y: ', -3237)
# ('x: ', 2431)
# ('y: ', -3241)
# ('x: ', 2434)
# ('y: ', -3245)
# ('x: ', 2437)
# ('y: ', -3249)
# ('x: ', 2440)
# ('y: ', -3253)
# ('x: ', 2443)
# ('y: ', -3257)
# ('x: ', 2446)
# ('y: ', -3261)
# ('x: ', 2449)
# ('y: ', -3265)
# ('x: ', 2452)
# ('y: ', -3269)
# ('x: ', 2455)
# ('y: ', -3273)
# ('x: ', 2458)
# ('y: ', -3277)
# ('x: ', 2461)
# ('y: ', -3281)
# ('x: ', 2464)
# ('y: ', -3285)
# ('x: ', 2467)
# ('y: ', -3289)
# ('x: ', 2470)
# ('y: ', -3293)
# ('x: ', 2473)
# ('y: ', -3297)
# ('x: ', 2476)
# ('y: ', -3301)
# ('x: ', 2479)
# ('y: ', -3305)
# ('x: ', 2482)
# ('y: ', -3309)
# ('x: ', 2485)
# ('y: ', -3313)
# ('x: ', 2488)
# ('y: ', -3317)
# ('x: ', 2491)
# ('y: ', -3321)
# ('x: ', 2494)
# ('y: ', -3325)
# ('x: ', 2497)
# ('y: ', -3329)
# ('x: ', 2500)
# ('y: ', -3333)
# ('x: ', 2503)
# ('y: ', -3337)
# ('x: ', 2506)
# ('y: ', -3341)
# ('x: ', 2509)
# ('y: ', -3345)
# ('x: ', 2512)
# ('y: ', -3349)
# ('x: ', 2515)
# ('y: ', -3353)
# ('x: ', 2518)
# ('y: ', -3357)
# ('x: ', 2521)
# ('y: ', -3361)
# ('x: ', 2524)
# ('y: ', -3365)
# ('x: ', 2527)
# ('y: ', -3369)
# ('x: ', 2530)
# ('y: ', -3373)
# ('x: ', 2533)
# ('y: ', -3377)
# ('x: ', 2536)
# ('y: ', -3381)
# ('x: ', 2539)
# ('y: ', -3385)
# ('x: ', 2542)
# ('y: ', -3389)
# ('x: ', 2545)
# ('y: ', -3393)
# ('x: ', 2548)
# ('y: ', -3397)
# ('x: ', 2551)
# ('y: ', -3401)
# ('x: ', 2554)
# ('y: ', -3405)
# ('x: ', 2557)
# ('y: ', -3409)
# ('x: ', 2560)
# ('y: ', -3413)
# ('x: ', 2563)
# ('y: ', -3417)
# ('x: ', 2566)
# ('y: ', -3421)
# ('x: ', 2569)
# ('y: ', -3425)
# ('x: ', 2572)
# ('y: ', -3429)
# ('x: ', 2575)
# ('y: ', -3433)
# ('x: ', 2578)
# ('y: ', -3437)
# ('x: ', 2581)
# ('y: ', -3441)
# ('x: ', 2584)
# ('y: ', -3445)
# ('x: ', 2587)
# ('y: ', -3449)
# ('x: ', 2590)
# ('y: ', -3453)
# ('x: ', 2593)
# ('y: ', -3457)
# ('x: ', 2596)
# ('y: ', -3461)
# ('x: ', 2599)
# ('y: ', -3465)
# ('x: ', 2602)
# ('y: ', -3469)
# ('x: ', 2605)
# ('y: ', -3473)
# ('x: ', 2608)
# ('y: ', -3477)
# ('x: ', 2611)
# ('y: ', -3481)
# ('x: ', 2614)
# ('y: ', -3485)
# ('x: ', 2617)
# ('y: ', -3489)
# ('x: ', 2620)
# ('y: ', -3493)
# ('x: ', 2623)
# ('y: ', -3497)
# ('x: ', 2626)
# ('y: ', -3501)
# ('x: ', 2629)
# ('y: ', -3505)
# ('x: ', 2632)
# ('y: ', -3509)
# ('x: ', 2635)
# ('y: ', -3513)
# ('x: ', 2638)
# ('y: ', -3517)
# ('x: ', 2641)
# ('y: ', -3521)
# ('x: ', 2644)
# ('y: ', -3525)
# ('x: ', 2647)
# ('y: ', -3529)
# ('x: ', 2650)
# ('y: ', -3533)
# ('x: ', 2653)
# ('y: ', -3537)
# ('x: ', 2656)
# ('y: ', -3541)
# ('x: ', 2659)
# ('y: ', -3545)
# ('x: ', 2662)
# ('y: ', -3549)
# ('x: ', 2665)
# ('y: ', -3553)
# ('x: ', 2668)
# ('y: ', -3557)
# ('x: ', 2671)
# ('y: ', -3561)
# ('x: ', 2674)
# ('y: ', -3565)
# ('x: ', 2677)
# ('y: ', -3569)
# ('x: ', 2680)
# ('y: ', -3573)
# ('x: ', 2683)
# ('y: ', -3577)
# ('x: ', 2686)
# ('y: ', -3581)
# ('x: ', 2689)
# ('y: ', -3585)
# ('x: ', 2692)
# ('y: ', -3589)
# ('x: ', 2695)
# ('y: ', -3593)
# ('x: ', 2698)
# ('y: ', -3597)
# ('x: ', 2701)
# ('y: ', -3601)
# ('x: ', 2704)
# ('y: ', -3605)
# ('x: ', 2707)
# ('y: ', -3609)
# ('x: ', 2710)
# ('y: ', -3613)
# ('x: ', 2713)
# ('y: ', -3617)
# ('x: ', 2716)
# ('y: ', -3621)
# ('x: ', 2719)
# ('y: ', -3625)
# ('x: ', 2722)
# ('y: ', -3629)
# ('x: ', 2725)
# ('y: ', -3633)
# ('x: ', 2728)
# ('y: ', -3637)
# ('x: ', 2731)
# ('y: ', -3641)
# ('x: ', 2734)
# ('y: ', -3645)
# ('x: ', 2737)
# ('y: ', -3649)
# ('x: ', 2740)
# ('y: ', -3653)
# ('x: ', 2743)
# ('y: ', -3657)
# ('x: ', 2746)
# ('y: ', -3661)
# ('x: ', 2749)
# ('y: ', -3665)
# ('x: ', 2752)
# ('y: ', -3669)
# ('x: ', 2755)
# ('y: ', -3673)
# ('x: ', 2758)
# ('y: ', -3677)
# ('x: ', 2761)
# ('y: ', -3681)
# ('x: ', 2764)
# ('y: ', -3685)
# ('x: ', 2767)
# ('y: ', -3689)
# ('x: ', 2770)
# ('y: ', -3693)
# ('x: ', 2773)
# ('y: ', -3697)
# ('x: ', 2776)
# ('y: ', -3701)
# ('x: ', 2779)
# ('y: ', -3705)
# ('x: ', 2782)
# ('y: ', -3709)
# ('x: ', 2785)
# ('y: ', -3713)
# ('x: ', 2788)
# ('y: ', -3717)
# ('x: ', 2791)
# ('y: ', -3721)
# ('x: ', 2794)
# ('y: ', -3725)
# ('x: ', 2797)
# ('y: ', -3729)
# ('x: ', 2800)
# ('y: ', -3733)
# ('x: ', 2803)
# ('y: ', -3737)
# ('x: ', 2806)
# ('y: ', -3741)
# ('x: ', 2809)
# ('y: ', -3745)
# ('x: ', 2812)
# ('y: ', -3749)
# ('x: ', 2815)
# ('y: ', -3753)
# ('x: ', 2818)
# ('y: ', -3757)
# ('x: ', 2821)
# ('y: ', -3761)
# ('x: ', 2824)
# ('y: ', -3765)
# ('x: ', 2827)
# ('y: ', -3769)
# ('x: ', 2830)
# ('y: ', -3773)
# ('x: ', 2833)
# ('y: ', -3777)
# ('x: ', 2836)
# ('y: ', -3781)
# ('x: ', 2839)
# ('y: ', -3785)
# ('x: ', 2842)
# ('y: ', -3789)
# ('x: ', 2845)
# ('y: ', -3793)
# ('x: ', 2848)
# ('y: ', -3797)
# ('x: ', 2851)
# ('y: ', -3801)
# ('x: ', 2854)
# ('y: ', -3805)
# ('x: ', 2857)
# ('y: ', -3809)
# ('x: ', 2860)
# ('y: ', -3813)
# ('x: ', 2863)
# ('y: ', -3817)
# ('x: ', 2866)
# ('y: ', -3821)
# ('x: ', 2869)
# ('y: ', -3825)
# ('x: ', 2872)
# ('y: ', -3829)
# ('x: ', 2875)
# ('y: ', -3833)
# ('x: ', 2878)
# ('y: ', -3837)
# ('x: ', 2881)
# ('y: ', -3841)
# ('x: ', 2884)
# ('y: ', -3845)
# ('x: ', 2887)
# ('y: ', -3849)
# ('x: ', 2890)
# ('y: ', -3853)
# ('x: ', 2893)
# ('y: ', -3857)
# ('x: ', 2896)
# ('y: ', -3861)
# ('x: ', 2899)
# ('y: ', -3865)
# ('x: ', 2902)
# ('y: ', -3869)
# ('x: ', 2905)
# ('y: ', -3873)
# ('x: ', 2908)
# ('y: ', -3877)
# ('x: ', 2911)
# ('y: ', -3881)
# ('x: ', 2914)
# ('y: ', -3885)
# ('x: ', 2917)
# ('y: ', -3889)
# ('x: ', 2920)
# ('y: ', -3893)
# ('x: ', 2923)
# ('y: ', -3897)
# ('x: ', 2926)
# ('y: ', -3901)
# ('x: ', 2929)
# ('y: ', -3905)
# ('x: ', 2932)
# ('y: ', -3909)
# ('x: ', 2935)
# ('y: ', -3913)
# ('x: ', 2938)
# ('y: ', -3917)
# ('x: ', 2941)
# ('y: ', -3921)
# ('x: ', 2944)
# ('y: ', -3925)
# ('x: ', 2947)
# ('y: ', -3929)
# ('x: ', 2950)
# ('y: ', -3933)
# ('x: ', 2953)
# ('y: ', -3937)
# ('x: ', 2956)
# ('y: ', -3941)
# ('x: ', 2959)
# ('y: ', -3945)
# ('x: ', 2962)
# ('y: ', -3949)
# ('x: ', 2965)
# ('y: ', -3953)
# ('x: ', 2968)
# ('y: ', -3957)
# ('x: ', 2971)
# ('y: ', -3961)
# ('x: ', 2974)
# ('y: ', -3965)
# ('x: ', 2977)
# ('y: ', -3969)
# ('x: ', 2980)
# ('y: ', -3973)
# ('x: ', 2983)
# ('y: ', -3977)
# ('x: ', 2986)
# ('y: ', -3981)
# ('x: ', 2989)
# ('y: ', -3985)
# ('x: ', 2992)
# ('y: ', -3989)
# ('x: ', 2995)
# ('y: ', -3993)
# ('x: ', 2998)
# ('y: ', -3997)
# ('x: ', 3001)
# ('y: ', -4001)
# ('x: ', 3004)
# ('y: ', -4005)
# ('x: ', 3007)
# ('y: ', -4009)
# ('x: ', 3010)
# ('y: ', -4013)
# ('x: ', 3013)
# ('y: ', -4017)
# ('x: ', 3016)
# ('y: ', -4021)
# ('x: ', 3019)
# ('y: ', -4025)
# ('x: ', 3022)
# ('y: ', -4029)
# ('x: ', 3025)
# ('y: ', -4033)
# ('x: ', 3028)
# ('y: ', -4037)
# ('x: ', 3031)
# ('y: ', -4041)
# ('x: ', 3034)
# ('y: ', -4045)
# ('x: ', 3037)
# ('y: ', -4049)
# ('x: ', 3040)
# ('y: ', -4053)
# ('x: ', 3043)
# ('y: ', -4057)
# ('x: ', 3046)
# ('y: ', -4061)
# ('x: ', 3049)
# ('y: ', -4065)
# ('x: ', 3052)
# ('y: ', -4069)
# ('x: ', 3055)
# ('y: ', -4073)
# ('x: ', 3058)
# ('y: ', -4077)
# ('x: ', 3061)
# ('y: ', -4081)
# ('x: ', 3064)
# ('y: ', -4085)
# ('x: ', 3067)
# ('y: ', -4089)
# ('x: ', 3070)
# ('y: ', -4093)
# ('x: ', 3073)
# ('y: ', -4097)
# ('x: ', 3076)
# ('y: ', -4101)
# ('x: ', 3079)
# ('y: ', -4105)
# ('x: ', 3082)
# ('y: ', -4109)
# ('x: ', 3085)
# ('y: ', -4113)
# ('x: ', 3088)
# ('y: ', -4117)
# ('x: ', 3091)
# ('y: ', -4121)
# ('x: ', 3094)
# ('y: ', -4125)
# ('x: ', 3097)
# ('y: ', -4129)
# ('x: ', 3100)
# ('y: ', -4133)
# ('x: ', 3103)
# ('y: ', -4137)
# ('x: ', 3106)
# ('y: ', -4141)
# ('x: ', 3109)
# ('y: ', -4145)
# ('x: ', 3112)
# ('y: ', -4149)
# ('x: ', 3115)
# ('y: ', -4153)
# ('x: ', 3118)
# ('y: ', -4157)
# ('x: ', 3121)
# ('y: ', -4161)
# ('x: ', 3124)
# ('y: ', -4165)
# ('x: ', 3127)
# ('y: ', -4169)
# ('x: ', 3130)
# ('y: ', -4173)
# ('x: ', 3133)
# ('y: ', -4177)
# ('x: ', 3136)
# ('y: ', -4181)
# ('x: ', 3139)
# ('y: ', -4185)
# ('x: ', 3142)
# ('y: ', -4189)
# ('x: ', 3145)
# ('y: ', -4193)
# ('x: ', 3148)
# ('y: ', -4197)
# ('x: ', 3151)
# ('y: ', -4201)
# ('x: ', 3154)
# ('y: ', -4205)
# ('x: ', 3157)
# ('y: ', -4209)
# ('x: ', 3160)
# ('y: ', -4213)
# ('x: ', 3163)
# ('y: ', -4217)
# ('x: ', 3166)
# ('y: ', -4221)
# ('x: ', 3169)
# ('y: ', -4225)
# ('x: ', 3172)
# ('y: ', -4229)
# ('x: ', 3175)
# ('y: ', -4233)
# ('x: ', 3178)
# ('y: ', -4237)
# ('x: ', 3181)
# ('y: ', -4241)
# ('x: ', 3184)
# ('y: ', -4245)
# ('x: ', 3187)
# ('y: ', -4249)
# ('x: ', 3190)
# ('y: ', -4253)
# ('x: ', 3193)
# ('y: ', -4257)
# ('x: ', 3196)
# ('y: ', -4261)
# ('x: ', 3199)
# ('y: ', -4265)
# ('x: ', 3202)
# ('y: ', -4269)
# ('x: ', 3205)
# ('y: ', -4273)
# ('x: ', 3208)
# ('y: ', -4277)
# ('x: ', 3211)
# ('y: ', -4281)
# ('x: ', 3214)
# ('y: ', -4285)
# ('x: ', 3217)
# ('y: ', -4289)
# ('x: ', 3220)
# ('y: ', -4293)
# ('x: ', 3223)
# ('y: ', -4297)
# ('x: ', 3226)
# ('y: ', -4301)
# ('x: ', 3229)
# ('y: ', -4305)
# ('x: ', 3232)
# ('y: ', -4309)
# ('x: ', 3235)
# ('y: ', -4313)
# ('x: ', 3238)
# ('y: ', -4317)
# ('x: ', 3241)
# ('y: ', -4321)
# ('x: ', 3244)
# ('y: ', -4325)
# ('x: ', 3247)
# ('y: ', -4329)
# ('x: ', 3250)
# ('y: ', -4333)
# ('x: ', 3253)
# ('y: ', -4337)
# ('x: ', 3256)
# ('y: ', -4341)
# ('x: ', 3259)
# ('y: ', -4345)
# ('x: ', 3262)
# ('y: ', -4349)
# ('x: ', 3265)
# ('y: ', -4353)
# ('x: ', 3268)
# ('y: ', -4357)
# ('x: ', 3271)
# ('y: ', -4361)
# ('x: ', 3274)
# ('y: ', -4365)
# ('x: ', 3277)
# ('y: ', -4369)
# ('x: ', 3280)
# ('y: ', -4373)
# ('x: ', 3283)
# ('y: ', -4377)
# ('x: ', 3286)
# ('y: ', -4381)
# ('x: ', 3289)
# ('y: ', -4385)
# ('x: ', 3292)
# ('y: ', -4389)
# ('x: ', 3295)
# ('y: ', -4393)
# ('x: ', 3298)
# ('y: ', -4397)
# ('x: ', 3301)
# ('y: ', -4401)
# ('x: ', 3304)
# ('y: ', -4405)
# ('x: ', 3307)
# ('y: ', -4409)
# ('x: ', 3310)
# ('y: ', -4413)
# ('x: ', 3313)
# ('y: ', -4417)
# ('x: ', 3316)
# ('y: ', -4421)
# ('x: ', 3319)
# ('y: ', -4425)
# ('x: ', 3322)
# ('y: ', -4429)
# ('x: ', 3325)
# ('y: ', -4433)
# ('x: ', 3328)
# ('y: ', -4437)
# ('x: ', 3331)
# ('y: ', -4441)
# ('x: ', 3334)
# ('y: ', -4445)
# ('x: ', 3337)
# ('y: ', -4449)
# ('x: ', 3340)
# ('y: ', -4453)
# ('x: ', 3343)
# ('y: ', -4457)
# ('x: ', 3346)
# ('y: ', -4461)
# ('x: ', 3349)
# ('y: ', -4465)
# ('x: ', 3352)
# ('y: ', -4469)
# ('x: ', 3355)
# ('y: ', -4473)
# ('x: ', 3358)
# ('y: ', -4477)
# ('x: ', 3361)
# ('y: ', -4481)
# ('x: ', 3364)
# ('y: ', -4485)
# ('x: ', 3367)
# ('y: ', -4489)
# ('x: ', 3370)
# ('y: ', -4493)
# ('x: ', 3373)
# ('y: ', -4497)
# ('x: ', 3376)
# ('y: ', -4501)
# ('x: ', 3379)
# ('y: ', -4505)
# ('x: ', 3382)
# ('y: ', -4509)
# ('x: ', 3385)
# ('y: ', -4513)
# ('x: ', 3388)
# ('y: ', -4517)
# ('x: ', 3391)
# ('y: ', -4521)
# ('x: ', 3394)
# ('y: ', -4525)
# ('x: ', 3397)
# ('y: ', -4529)
# ('x: ', 3400)
# ('y: ', -4533)
# ('x: ', 3403)
# ('y: ', -4537)
# ('x: ', 3406)
# ('y: ', -4541)
# ('x: ', 3409)
# ('y: ', -4545)
# ('x: ', 3412)
# ('y: ', -4549)
# ('x: ', 3415)
# ('y: ', -4553)
# ('x: ', 3418)
# ('y: ', -4557)
# ('x: ', 3421)
# ('y: ', -4561)
# ('x: ', 3424)
# ('y: ', -4565)
# ('x: ', 3427)
# ('y: ', -4569)
# ('x: ', 3430)
# ('y: ', -4573)
# ('x: ', 3433)
# ('y: ', -4577)
# ('x: ', 3436)
# ('y: ', -4581)
# ('x: ', 3439)
# ('y: ', -4585)
# ('x: ', 3442)
# ('y: ', -4589)
# ('x: ', 3445)
# ('y: ', -4593)
# ('x: ', 3448)
# ('y: ', -4597)
# ('x: ', 3451)
# ('y: ', -4601)
# ('x: ', 3454)
# ('y: ', -4605)
# ('x: ', 3457)
# ('y: ', -4609)
# ('x: ', 3460)
# ('y: ', -4613)
# ('x: ', 3463)
# ('y: ', -4617)
# ('x: ', 3466)
# ('y: ', -4621)
# ('x: ', 3469)
# ('y: ', -4625)
# ('x: ', 3472)
# ('y: ', -4629)
# ('x: ', 3475)
# ('y: ', -4633)
# ('x: ', 3478)
# ('y: ', -4637)
# ('x: ', 3481)
# ('y: ', -4641)
# ('x: ', 3484)
# ('y: ', -4645)
# ('x: ', 3487)
# ('y: ', -4649)
# ('x: ', 3490)
# ('y: ', -4653)
# ('x: ', 3493)
# ('y: ', -4657)
# ('x: ', 3496)
# ('y: ', -4661)
# ('x: ', 3499)
# ('y: ', -4665)
# ('x: ', 3502)
# ('y: ', -4669)
# ('x: ', 3505)
# ('y: ', -4673)
# ('x: ', 3508)
# ('y: ', -4677)
# ('x: ', 3511)
# ('y: ', -4681)
# ('x: ', 3514)
# ('y: ', -4685)
# ('x: ', 3517)
# ('y: ', -4689)
# ('x: ', 3520)
# ('y: ', -4693)
# ('x: ', 3523)
# ('y: ', -4697)
# ('x: ', 3526)
# ('y: ', -4701)
# ('x: ', 3529)
# ('y: ', -4705)
# ('x: ', 3532)
# ('y: ', -4709)
# ('x: ', 3535)
# ('y: ', -4713)
# ('x: ', 3538)
# ('y: ', -4717)
# ('x: ', 3541)
# ('y: ', -4721)
# ('x: ', 3544)
# ('y: ', -4725)
# ('x: ', 3547)
# ('y: ', -4729)
# ('x: ', 3550)
# ('y: ', -4733)
# ('x: ', 3553)
# ('y: ', -4737)
# ('x: ', 3556)
# ('y: ', -4741)
# ('x: ', 3559)
# ('y: ', -4745)
# ('x: ', 3562)
# ('y: ', -4749)
# ('x: ', 3565)
# ('y: ', -4753)
# ('x: ', 3568)
# ('y: ', -4757)
# ('x: ', 3571)
# ('y: ', -4761)
# ('x: ', 3574)
# ('y: ', -4765)
# ('x: ', 3577)
# ('y: ', -4769)
# ('x: ', 3580)
# ('y: ', -4773)
# ('x: ', 3583)
# ('y: ', -4777)
# ('x: ', 3586)
# ('y: ', -4781)
# ('x: ', 3589)
# ('y: ', -4785)
# ('x: ', 3592)
# ('y: ', -4789)
# ('x: ', 3595)
# ('y: ', -4793)
# ('x: ', 3598)
# ('y: ', -4797)
# ('x: ', 3601)
# ('y: ', -4801)
# ('x: ', 3604)
# ('y: ', -4805)
# ('x: ', 3607)
# ('y: ', -4809)
# ('x: ', 3610)
# ('y: ', -4813)
# ('x: ', 3613)
# ('y: ', -4817)
# ('x: ', 3616)
# ('y: ', -4821)
# ('x: ', 3619)
# ('y: ', -4825)
# ('x: ', 3622)
# ('y: ', -4829)
# ('x: ', 3625)
# ('y: ', -4833)
# ('x: ', 3628)
# ('y: ', -4837)
# ('x: ', 3631)
# ('y: ', -4841)
# ('x: ', 3634)
# ('y: ', -4845)
# ('x: ', 3637)
# ('y: ', -4849)
# ('x: ', 3640)
# ('y: ', -4853)
# ('x: ', 3643)
# ('y: ', -4857)
# ('x: ', 3646)
# ('y: ', -4861)
# ('x: ', 3649)
# ('y: ', -4865)
# ('x: ', 3652)
# ('y: ', -4869)
# ('x: ', 3655)
# ('y: ', -4873)
# ('x: ', 3658)
# ('y: ', -4877)
# ('x: ', 3661)
# ('y: ', -4881)
# ('x: ', 3664)
# ('y: ', -4885)
# ('x: ', 3667)
# ('y: ', -4889)
# ('x: ', 3670)
# ('y: ', -4893)
# ('x: ', 3673)
# ('y: ', -4897)
# ('x: ', 3676)
# ('y: ', -4901)
# ('x: ', 3679)
# ('y: ', -4905)
# ('x: ', 3682)
# ('y: ', -4909)
# ('x: ', 3685)
# ('y: ', -4913)
# ('x: ', 3688)
# ('y: ', -4917)
# ('x: ', 3691)
# ('y: ', -4921)
# ('x: ', 3694)
# ('y: ', -4925)
# ('x: ', 3697)
# ('y: ', -4929)
# ('x: ', 3700)
# ('y: ', -4933)
# ('x: ', 3703)
# ('y: ', -4937)
# ('x: ', 3706)
# ('y: ', -4941)
# ('x: ', 3709)
# ('y: ', -4945)
# ('x: ', 3712)
# ('y: ', -4949)
# ('x: ', 3715)
# ('y: ', -4953)
# ('x: ', 3718)
# ('y: ', -4957)
# ('x: ', 3721)
# ('y: ', -4961)
# ('x: ', 3724)
# ('y: ', -4965)
# ('x: ', 3727)
# ('y: ', -4969)
# ('x: ', 3730)
# ('y: ', -4973)
# ('x: ', 3733)
# ('y: ', -4977)
# ('x: ', 3736)
# ('y: ', -4981)
# ('x: ', 3739)
# ('y: ', -4985)
# ('x: ', 3742)
# ('y: ', -4989)
# ('x: ', 3745)
# ('y: ', -4993)
# ('x: ', 3748)
# ('y: ', -4997)
# ('x: ', 3751)
# ('y: ', -5001)
# ('x: ', 3754)
# ('y: ', -5005)
# ('x: ', 3757)
# ('y: ', -5009)
# ('x: ', 3760)
# ('y: ', -5013)
# ('x: ', 3763)
# ('y: ', -5017)
# ('x: ', 3766)
# ('y: ', -5021)
# ('x: ', 3769)
# ('y: ', -5025)
# ('x: ', 3772)
# ('y: ', -5029)
# ('x: ', 3775)
# ('y: ', -5033)
# ('x: ', 3778)
# ('y: ', -5037)
# ('x: ', 3781)
# ('y: ', -5041)
# ('x: ', 3784)
# ('y: ', -5045)
# ('x: ', 3787)
# ('y: ', -5049)
# ('x: ', 3790)
# ('y: ', -5053)
# ('x: ', 3793)
# ('y: ', -5057)
# ('x: ', 3796)
# ('y: ', -5061)
# ('x: ', 3799)
# ('y: ', -5065)
# ('x: ', 3802)
# ('y: ', -5069)
# ('x: ', 3805)
# ('y: ', -5073)
# ('x: ', 3808)
# ('y: ', -5077)
# ('x: ', 3811)
# ('y: ', -5081)
# ('x: ', 3814)
# ('y: ', -5085)
# ('x: ', 3817)
# ('y: ', -5089)
# ('x: ', 3820)
# ('y: ', -5093)
# ('x: ', 3823)
# ('y: ', -5097)
# ('x: ', 3826)
# ('y: ', -5101)
# ('x: ', 3829)
# ('y: ', -5105)
# ('x: ', 3832)
# ('y: ', -5109)
# ('x: ', 3835)
# ('y: ', -5113)
# ('x: ', 3838)
# ('y: ', -5117)
# ('x: ', 3841)
# ('y: ', -5121)
# ('x: ', 3844)
# ('y: ', -5125)
# ('x: ', 3847)
# ('y: ', -5129)
# ('x: ', 3850)
# ('y: ', -5133)
# ('x: ', 3853)
# ('y: ', -5137)
# ('x: ', 3856)
# ('y: ', -5141)
# ('x: ', 3859)
# ('y: ', -5145)
# ('x: ', 3862)
# ('y: ', -5149)
# ('x: ', 3865)
# ('y: ', -5153)
# ('x: ', 3868)
# ('y: ', -5157)
# ('x: ', 3871)
# ('y: ', -5161)
# ('x: ', 3874)
# ('y: ', -5165)
# ('x: ', 3877)
# ('y: ', -5169)
# ('x: ', 3880)
# ('y: ', -5173)
# ('x: ', 3883)
# ('y: ', -5177)
# ('x: ', 3886)
# ('y: ', -5181)
# ('x: ', 3889)
# ('y: ', -5185)
# ('x: ', 3892)
# ('y: ', -5189)
# ('x: ', 3895)
# ('y: ', -5193)
# ('x: ', 3898)
# ('y: ', -5197)
# ('x: ', 3901)
# ('y: ', -5201)
# ('x: ', 3904)
# ('y: ', -5205)
# ('x: ', 3907)
# ('y: ', -5209)
# ('x: ', 3910)
# ('y: ', -5213)
# ('x: ', 3913)
# ('y: ', -5217)
# ('x: ', 3916)
# ('y: ', -5221)
# ('x: ', 3919)
# ('y: ', -5225)
# ('x: ', 3922)
# ('y: ', -5229)
# ('x: ', 3925)
# ('y: ', -5233)
# ('x: ', 3928)
# ('y: ', -5237)
# ('x: ', 3931)
# ('y: ', -5241)
# ('x: ', 3934)
# ('y: ', -5245)
# ('x: ', 3937)
# ('y: ', -5249)
# ('x: ', 3940)
# ('y: ', -5253)
# ('x: ', 3943)
# ('y: ', -5257)
# ('x: ', 3946)
# ('y: ', -5261)
# ('x: ', 3949)
# ('y: ', -5265)
# ('x: ', 3952)
# ('y: ', -5269)
# ('x: ', 3955)
# ('y: ', -5273)
# ('x: ', 3958)
# ('y: ', -5277)
# ('x: ', 3961)
# ('y: ', -5281)
# ('x: ', 3964)
# ('y: ', -5285)
# ('x: ', 3967)
# ('y: ', -5289)
# ('x: ', 3970)
# ('y: ', -5293)
# ('x: ', 3973)
# ('y: ', -5297)
# ('x: ', 3976)
# ('y: ', -5301)
# ('x: ', 3979)
# ('y: ', -5305)
# ('x: ', 3982)
# ('y: ', -5309)
# ('x: ', 3985)
# ('y: ', -5313)
# ('x: ', 3988)
# ('y: ', -5317)
# ('x: ', 3991)
# ('y: ', -5321)
# ('x: ', 3994)
# ('y: ', -5325)
# ('x: ', 3997)
# ('y: ', -5329)
# ('x: ', 4000)
# ('y: ', -5333)
# ('x: ', 4003)
# ('y: ', -5337)
# ('x: ', 4006)
# ('y: ', -5341)
# ('x: ', 4009)
# ('y: ', -5345)
# ('x: ', 4012)
# ('y: ', -5349)
# ('x: ', 4015)
# ('y: ', -5353)
# ('x: ', 4018)
# ('y: ', -5357)
# ('x: ', 4021)
# ('y: ', -5361)
# ('x: ', 4024)
# ('y: ', -5365)
# ('x: ', 4027)
# ('y: ', -5369)
# ('x: ', 4030)
# ('y: ', -5373)
# ('x: ', 4033)
# ('y: ', -5377)
# ('x: ', 4036)
# ('y: ', -5381)
# ('x: ', 4039)
# ('y: ', -5385)
# ('x: ', 4042)
# ('y: ', -5389)
# ('x: ', 4045)
# ('y: ', -5393)
# ('x: ', 4048)
# ('y: ', -5397)
# ('x: ', 4051)
# ('y: ', -5401)
# ('x: ', 4054)
# ('y: ', -5405)
# ('x: ', 4057)
# ('y: ', -5409)
# ('x: ', 4060)
# ('y: ', -5413)
# ('x: ', 4063)
# ('y: ', -5417)
# ('x: ', 4066)
# ('y: ', -5421)
# ('x: ', 4069)
# ('y: ', -5425)
# ('x: ', 4072)
# ('y: ', -5429)
# ('x: ', 4075)
# ('y: ', -5433)
# ('x: ', 4078)
# ('y: ', -5437)
# ('x: ', 4081)
# ('y: ', -5441)
# ('x: ', 4084)
# ('y: ', -5445)
# ('x: ', 4087)
# ('y: ', -5449)
# ('x: ', 4090)
# ('y: ', -5453)
# ('x: ', 4093)
# ('y: ', -5457)
# ('x: ', 4096)
# ('y: ', -5461)
# ('x: ', 4099)
# ('y: ', -5465)
# ('x: ', 4102)
# ('y: ', -5469)
# ('x: ', 4105)
# ('y: ', -5473)
# ('x: ', 4108)
# ('y: ', -5477)
# ('x: ', 4111)
# ('y: ', -5481)
# ('x: ', 4114)
# ('y: ', -5485)
# ('x: ', 4117)
# ('y: ', -5489)
# ('x: ', 4120)
# ('y: ', -5493)
# ('x: ', 4123)
# ('y: ', -5497)
# ('x: ', 4126)
# ('y: ', -5501)
# ('x: ', 4129)
# ('y: ', -5505)
# ('x: ', 4132)
# ('y: ', -5509)
# ('x: ', 4135)
# ('y: ', -5513)
# ('x: ', 4138)
# ('y: ', -5517)
# ('x: ', 4141)
# ('y: ', -5521)
# ('x: ', 4144)
# ('y: ', -5525)
# ('x: ', 4147)
# ('y: ', -5529)
# ('x: ', 4150)
# ('y: ', -5533)
# ('x: ', 4153)
# ('y: ', -5537)
# ('x: ', 4156)
# ('y: ', -5541)
# ('x: ', 4159)
# ('y: ', -5545)
# ('x: ', 4162)
# ('y: ', -5549)
# ('x: ', 4165)
# ('y: ', -5553)
# ('x: ', 4168)
# ('y: ', -5557)
# ('x: ', 4171)
# ('y: ', -5561)
# ('x: ', 4174)
# ('y: ', -5565)
# ('x: ', 4177)
# ('y: ', -5569)
# ('x: ', 4180)
# ('y: ', -5573)
# ('x: ', 4183)
# ('y: ', -5577)
# ('x: ', 4186)
# ('y: ', -5581)
# ('x: ', 4189)
# ('y: ', -5585)
# ('x: ', 4192)
# ('y: ', -5589)
# ('x: ', 4195)
# ('y: ', -5593)
# ('x: ', 4198)
# ('y: ', -5597)
# ('x: ', 4201)
# ('y: ', -5601)
# ('x: ', 4204)
# ('y: ', -5605)
# ('x: ', 4207)
# ('y: ', -5609)
# ('x: ', 4210)
# ('y: ', -5613)
# ('x: ', 4213)
# ('y: ', -5617)
# ('x: ', 4216)
# ('y: ', -5621)
# ('x: ', 4219)
# ('y: ', -5625)
# ('x: ', 4222)
# ('y: ', -5629)
# ('x: ', 4225)
# ('y: ', -5633)
# ('x: ', 4228)
# ('y: ', -5637)
# ('x: ', 4231)
# ('y: ', -5641)
# ('x: ', 4234)
# ('y: ', -5645)
# ('x: ', 4237)
# ('y: ', -5649)
# ('x: ', 4240)
# ('y: ', -5653)
# ('x: ', 4243)
# ('y: ', -5657)
# ('x: ', 4246)
# ('y: ', -5661)
# ('x: ', 4249)
# ('y: ', -5665)
# ('x: ', 4252)
# ('y: ', -5669)
# ('x: ', 4255)
# ('y: ', -5673)
# ('x: ', 4258)
# ('y: ', -5677)
# ('x: ', 4261)
# ('y: ', -5681)
# ('x: ', 4264)
# ('y: ', -5685)
# ('x: ', 4267)
# ('y: ', -5689)
# ('x: ', 4270)
# ('y: ', -5693)
# ('x: ', 4273)
# ('y: ', -5697)
# ('x: ', 4276)
# ('y: ', -5701)
# ('x: ', 4279)
# ('y: ', -5705)
# ('x: ', 4282)
# ('y: ', -5709)
# ('x: ', 4285)
# ('y: ', -5713)
# ('x: ', 4288)
# ('y: ', -5717)
# ('x: ', 4291)
# ('y: ', -5721)
# ('x: ', 4294)
# ('y: ', -5725)
# ('x: ', 4297)
# ('y: ', -5729)
# ('x: ', 4300)
# ('y: ', -5733)
# ('x: ', 4303)
# ('y: ', -5737)
# ('x: ', 4306)
# ('y: ', -5741)
# ('x: ', 4309)
# ('y: ', -5745)
# ('x: ', 4312)
# ('y: ', -5749)
# ('x: ', 4315)
# ('y: ', -5753)
# ('x: ', 4318)
# ('y: ', -5757)
# ('x: ', 4321)
# ('y: ', -5761)
# ('x: ', 4324)
# ('y: ', -5765)
# ('x: ', 4327)
# ('y: ', -5769)
# ('x: ', 4330)
# ('y: ', -5773)
# ('x: ', 4333)
# ('y: ', -5777)
# ('x: ', 4336)
# ('y: ', -5781)
# ('x: ', 4339)
# ('y: ', -5785)
# ('x: ', 4342)
# ('y: ', -5789)
# ('x: ', 4345)
# ('y: ', -5793)
# ('x: ', 4348)
# ('y: ', -5797)
# ('x: ', 4351)
# ('y: ', -5801)
# ('x: ', 4354)
# ('y: ', -5805)
# ('x: ', 4357)
# ('y: ', -5809)
# ('x: ', 4360)
# ('y: ', -5813)
# ('x: ', 4363)
# ('y: ', -5817)
# ('x: ', 4366)
# ('y: ', -5821)
# ('x: ', 4369)
# ('y: ', -5825)
# ('x: ', 4372)
# ('y: ', -5829)
# ('x: ', 4375)
# ('y: ', -5833)
# ('x: ', 4378)
# ('y: ', -5837)
# ('x: ', 4381)
# ('y: ', -5841)
# ('x: ', 4384)
# ('y: ', -5845)
# ('x: ', 4387)
# ('y: ', -5849)
# ('x: ', 4390)
# ('y: ', -5853)
# ('x: ', 4393)
# ('y: ', -5857)
# ('x: ', 4396)
# ('y: ', -5861)
# ('x: ', 4399)
# ('y: ', -5865)
# ('x: ', 4402)
# ('y: ', -5869)
# ('x: ', 4405)
# ('y: ', -5873)
# ('x: ', 4408)
# ('y: ', -5877)
# ('x: ', 4411)
# ('y: ', -5881)
# ('x: ', 4414)
# ('y: ', -5885)
# ('x: ', 4417)
# ('y: ', -5889)
# ('x: ', 4420)
# ('y: ', -5893)
# ('x: ', 4423)
# ('y: ', -5897)
# ('x: ', 4426)
# ('y: ', -5901)
# ('x: ', 4429)
# ('y: ', -5905)
# ('x: ', 4432)
# ('y: ', -5909)
# ('x: ', 4435)
# ('y: ', -5913)
# ('x: ', 4438)
# ('y: ', -5917)
# ('x: ', 4441)
# ('y: ', -5921)
# ('x: ', 4444)
# ('y: ', -5925)
# ('x: ', 4447)
# ('y: ', -5929)
# ('x: ', 4450)
# ('y: ', -5933)
# ('x: ', 4453)
# ('y: ', -5937)
# ('x: ', 4456)
# ('y: ', -5941)
# ('x: ', 4459)
# ('y: ', -5945)
# ('x: ', 4462)
# ('y: ', -5949)
# ('x: ', 4465)
# ('y: ', -5953)
# ('x: ', 4468)
# ('y: ', -5957)
# ('x: ', 4471)
# ('y: ', -5961)
# ('x: ', 4474)
# ('y: ', -5965)
# ('x: ', 4477)
# ('y: ', -5969)
# ('x: ', 4480)
# ('y: ', -5973)
# ('x: ', 4483)
# ('y: ', -5977)
# ('x: ', 4486)
# ('y: ', -5981)
# ('x: ', 4489)
# ('y: ', -5985)
# ('x: ', 4492)
# ('y: ', -5989)
# ('x: ', 4495)
# ('y: ', -5993)
# ('x: ', 4498)
# ('y: ', -5997)
# ('x: ', 4501)
# ('y: ', -6001)
# ('x: ', 4504)
# ('y: ', -6005)
# ('x: ', 4507)
# ('y: ', -6009)
# ('x: ', 4510)
# ('y: ', -6013)
# ('x: ', 4513)
# ('y: ', -6017)
# ('x: ', 4516)
# ('y: ', -6021)
# ('x: ', 4519)
# ('y: ', -6025)
# ('x: ', 4522)
# ('y: ', -6029)
# ('x: ', 4525)
# ('y: ', -6033)
# ('x: ', 4528)
# ('y: ', -6037)
# ('x: ', 4531)
# ('y: ', -6041)
# ('x: ', 4534)
# ('y: ', -6045)
# ('x: ', 4537)
# ('y: ', -6049)
# ('x: ', 4540)
# ('y: ', -6053)
# ('x: ', 4543)
# ('y: ', -6057)
# ('x: ', 4546)
# ('y: ', -6061)
# ('x: ', 4549)
# ('y: ', -6065)
# ('x: ', 4552)
# ('y: ', -6069)
# ('x: ', 4555)
# ('y: ', -6073)
# ('x: ', 4558)
# ('y: ', -6077)
# ('x: ', 4561)
# ('y: ', -6081)
# ('x: ', 4564)
# ('y: ', -6085)
# ('x: ', 4567)
# ('y: ', -6089)
# ('x: ', 4570)
# ('y: ', -6093)
# ('x: ', 4573)
# ('y: ', -6097)
# ('x: ', 4576)
# ('y: ', -6101)
# ('x: ', 4579)
# ('y: ', -6105)
# ('x: ', 4582)
# ('y: ', -6109)
# ('x: ', 4585)
# ('y: ', -6113)
# ('x: ', 4588)
# ('y: ', -6117)
# ('x: ', 4591)
# ('y: ', -6121)
# ('x: ', 4594)
# ('y: ', -6125)
# ('x: ', 4597)
# ('y: ', -6129)
# ('x: ', 4600)
# ('y: ', -6133)
# ('x: ', 4603)
# ('y: ', -6137)
# ('x: ', 4606)
# ('y: ', -6141)
# ('x: ', 4609)
# ('y: ', -6145)
# ('x: ', 4612)
# ('y: ', -6149)
# ('x: ', 4615)
# ('y: ', -6153)
# ('x: ', 4618)
# ('y: ', -6157)
# ('x: ', 4621)
# ('y: ', -6161)
# ('x: ', 4624)
# ('y: ', -6165)
# ('x: ', 4627)
# ('y: ', -6169)
# ('x: ', 4630)
# ('y: ', -6173)
# ('x: ', 4633)
# ('y: ', -6177)
# ('x: ', 4636)
# ('y: ', -6181)
# ('x: ', 4639)
# ('y: ', -6185)
# ('x: ', 4642)
# ('y: ', -6189)
# ('x: ', 4645)
# ('y: ', -6193)
# ('x: ', 4648)
# ('y: ', -6197)
# ('x: ', 4651)
# ('y: ', -6201)
# ('x: ', 4654)
# ('y: ', -6205)
# ('x: ', 4657)
# ('y: ', -6209)
# ('x: ', 4660)
# ('y: ', -6213)
# ('x: ', 4663)
# ('y: ', -6217)
# ('x: ', 4666)
# ('y: ', -6221)
# ('x: ', 4669)
# ('y: ', -6225)
# ('x: ', 4672)
# ('y: ', -6229)
# ('x: ', 4675)
# ('y: ', -6233)
# ('x: ', 4678)
# ('y: ', -6237)
# ('x: ', 4681)
# ('y: ', -6241)
# ('x: ', 4684)
# ('y: ', -6245)
# ('x: ', 4687)
# ('y: ', -6249)
# ('x: ', 4690)
# ('y: ', -6253)
# ('x: ', 4693)
# ('y: ', -6257)
# ('x: ', 4696)
# ('y: ', -6261)
# ('x: ', 4699)
# ('y: ', -6265)
# ('x: ', 4702)
# ('y: ', -6269)
# ('x: ', 4705)
# ('y: ', -6273)
# ('x: ', 4708)
# ('y: ', -6277)
# ('x: ', 4711)
# ('y: ', -6281)
# ('x: ', 4714)
# ('y: ', -6285)
# ('x: ', 4717)
# ('y: ', -6289)
# ('x: ', 4720)
# ('y: ', -6293)
# ('x: ', 4723)
# ('y: ', -6297)
# ('x: ', 4726)
# ('y: ', -6301)
# ('x: ', 4729)
# ('y: ', -6305)
# ('x: ', 4732)
# ('y: ', -6309)
# ('x: ', 4735)
# ('y: ', -6313)
# ('x: ', 4738)
# ('y: ', -6317)
# ('x: ', 4741)
# ('y: ', -6321)
# ('x: ', 4744)
# ('y: ', -6325)
# ('x: ', 4747)
# ('y: ', -6329)
# ('x: ', 4750)
# ('y: ', -6333)
# ('x: ', 4753)
# ('y: ', -6337)
# ('x: ', 4756)
# ('y: ', -6341)
# ('x: ', 4759)
# ('y: ', -6345)
# ('x: ', 4762)
# ('y: ', -6349)
# ('x: ', 4765)
# ('y: ', -6353)
# ('x: ', 4768)
# ('y: ', -6357)
# ('x: ', 4771)
# ('y: ', -6361)
# ('x: ', 4774)
# ('y: ', -6365)
# ('x: ', 4777)
# ('y: ', -6369)
# ('x: ', 4780)
# ('y: ', -6373)
# ('x: ', 4783)
# ('y: ', -6377)
# ('x: ', 4786)
# ('y: ', -6381)
# ('x: ', 4789)
# ('y: ', -6385)
# ('x: ', 4792)
# ('y: ', -6389)
# ('x: ', 4795)
# ('y: ', -6393)
# ('x: ', 4798)
# ('y: ', -6397)
# ('x: ', 4801)
# ('y: ', -6401)
# ('x: ', 4804)
# ('y: ', -6405)
# ('x: ', 4807)
# ('y: ', -6409)
# ('x: ', 4810)
# ('y: ', -6413)
# ('x: ', 4813)
# ('y: ', -6417)
# ('x: ', 4816)
# ('y: ', -6421)
# ('x: ', 4819)
# ('y: ', -6425)
# ('x: ', 4822)
# ('y: ', -6429)
# ('x: ', 4825)
# ('y: ', -6433)
# ('x: ', 4828)
# ('y: ', -6437)
# ('x: ', 4831)
# ('y: ', -6441)
# ('x: ', 4834)
# ('y: ', -6445)
# ('x: ', 4837)
# ('y: ', -6449)
# ('x: ', 4840)
# ('y: ', -6453)
# ('x: ', 4843)
# ('y: ', -6457)
# ('x: ', 4846)
# ('y: ', -6461)
# ('x: ', 4849)
# ('y: ', -6465)
# ('x: ', 4852)
# ('y: ', -6469)
# ('x: ', 4855)
# ('y: ', -6473)
# ('x: ', 4858)
# ('y: ', -6477)
# ('x: ', 4861)
# ('y: ', -6481)
# ('x: ', 4864)
# ('y: ', -6485)
# ('x: ', 4867)
# ('y: ', -6489)
# ('x: ', 4870)
# ('y: ', -6493)
# ('x: ', 4873)
# ('y: ', -6497)
# ('x: ', 4876)
# ('y: ', -6501)
# ('x: ', 4879)
# ('y: ', -6505)
# ('x: ', 4882)
# ('y: ', -6509)
# ('x: ', 4885)
# ('y: ', -6513)
# ('x: ', 4888)
# ('y: ', -6517)
# ('x: ', 4891)
# ('y: ', -6521)
# ('x: ', 4894)
# ('y: ', -6525)
# ('x: ', 4897)
# ('y: ', -6529)
# ('x: ', 4900)
# ('y: ', -6533)
# ('x: ', 4903)
# ('y: ', -6537)
# ('x: ', 4906)
# ('y: ', -6541)
# ('x: ', 4909)
# ('y: ', -6545)
# ('x: ', 4912)
# ('y: ', -6549)
# ('x: ', 4915)
# ('y: ', -6553)
# ('x: ', 4918)
# ('y: ', -6557)
# ('x: ', 4921)
# ('y: ', -6561)
# ('x: ', 4924)
# ('y: ', -6565)
# ('x: ', 4927)
# ('y: ', -6569)
# ('x: ', 4930)
# ('y: ', -6573)
# ('x: ', 4933)
# ('y: ', -6577)
# ('x: ', 4936)
# ('y: ', -6581)
# ('x: ', 4939)
# ('y: ', -6585)
# ('x: ', 4942)
# ('y: ', -6589)
# ('x: ', 4945)
# ('y: ', -6593)
# ('x: ', 4948)
# ('y: ', -6597)
# ('x: ', 4951)
# ('y: ', -6601)
# ('x: ', 4954)
# ('y: ', -6605)
# ('x: ', 4957)
# ('y: ', -6609)
# ('x: ', 4960)
# ('y: ', -6613)
# ('x: ', 4963)
# ('y: ', -6617)
# ('x: ', 4966)
# ('y: ', -6621)
# ('x: ', 4969)
# ('y: ', -6625)
# ('x: ', 4972)
# ('y: ', -6629)
# ('x: ', 4975)
# ('y: ', -6633)
# ('x: ', 4978)
# ('y: ', -6637)
# ('x: ', 4981)
# ('y: ', -6641)
# ('x: ', 4984)
# ('y: ', -6645)
# ('x: ', 4987)
# ('y: ', -6649)
# ('x: ', 4990)
# ('y: ', -6653)
# ('x: ', 4993)
# ('y: ', -6657)
# ('x: ', 4996)
# ('y: ', -6661)
# ('x: ', 4999)
# ('y: ', -6665)
# ('x: ', 5002)
# ('y: ', -6669)
# ('x: ', 5005)
# ('y: ', -6673)
# ('x: ', 5008)
# ('y: ', -6677)
# ('x: ', 5011)
# ('y: ', -6681)
# ('x: ', 5014)
# ('y: ', -6685)
# ('x: ', 5017)
# ('y: ', -6689)
# ('x: ', 5020)
# ('y: ', -6693)
# ('x: ', 5023)
# ('y: ', -6697)
# ('x: ', 5026)
# ('y: ', -6701)
# ('x: ', 5029)
# ('y: ', -6705)
# ('x: ', 5032)
# ('y: ', -6709)
# ...
# ('x: ', 114946)
# ('y: ', -153261)
# ('x: ', 114949)
# ('y: ', -153265)
# ('x: ', 114952)
# ('y: ', -153269)
# ('x: ', 114955)
# ('y: ', -153273)
# ('x: ', 114958)
# ('y: ', -153277)
# ('x: ', 114961)
# ('y: ', -153281)
# ('x: ', 114964)
# ('y: ', -153285)
# ('x: ', 114967)
# ('y: ', -153289)
# ('x: ', 114970)
# ('y: ', -153293)
# ('x: ', 114973)
# ('y: ', -153297)
# ('x: ', 114976)
# ('y: ', -153301)
# ('x: ', 114979)
# ('y: ', -153305)
# ('x: ', 114982)
# ('y: ', -153309)
# ('x: ', 114985)
# ('y: ', -153313)
# ('x: ', 114988)
# ('y: ', -153317)
# ('x: ', 114991)
# ('y: ', -153321)
# ('x: ', 114994)
# ('y: ', -153325)
# ('x: ', 114997)
# ('y: ', -153329)
# ('x: ', 115000)
# ('y: ', -153333)
# ('x: ', 115003)
# ('y: ', -153337)
# ('x: ', 115006)
# ('y: ', -153341)
# ('x: ', 115009)
# ('y: ', -153345)
# ('x: ', 115012)
# ('y: ', -153349)
# ('x: ', 115015)
# ('y: ', -153353)
# ('x: ', 115018)
# ('y: ', -153357)
# ('x: ', 115021)
# ('y: ', -153361)
# ('x: ', 115024)
# ('y: ', -153365)
# ('x: ', 115027)
# ('y: ', -153369)
# ('x: ', 115030)
# ('y: ', -153373)
# ('x: ', 115033)
# ('y: ', -153377)
# ('x: ', 115036)
# ('y: ', -153381)
# ('x: ', 115039)
# ('y: ', -153385)
# ('x: ', 115042)
# ('y: ', -153389)
# ('x: ', 115045)
# ('y: ', -153393)
# ('x: ', 115048)
# ('y: ', -153397)
# ('x: ', 115051)
# ('y: ', -153401)
# ('x: ', 115054)
# ('y: ', -153405)
# ('x: ', 115057)
# ('y: ', -153409)
# ('x: ', 115060)
# ('y: ', -153413)
# ('x: ', 115063)
# ('y: ', -153417)
# ('x: ', 115066)
# ('y: ', -153421)
# ('x: ', 115069)
# ('y: ', -153425)
# ('x: ', 115072)
# ('y: ', -153429)
# ('x: ', 115075)
# ('y: ', -153433)
# ('x: ', 115078)
# ('y: ', -153437)
# ('x: ', 115081)
# ('y: ', -153441)
# ('x: ', 115084)
# ('y: ', -153445)
# ('x: ', 115087)
# ('y: ', -153449)
# ('x: ', 115090)
# ('y: ', -153453)
# ('x: ', 115093)
# ('y: ', -153457)
# ('x: ', 115096)
# ('y: ', -153461)
# ('x: ', 115099)
# ('y: ', -153465)
# ('x: ', 115102)
# ('y: ', -153469)
# ('x: ', 115105)
# ('y: ', -153473)
# ('x: ', 115108)
# ('y: ', -153477)
# ('x: ', 115111)
# ('y: ', -153481)
# ('x: ', 115114)
# ('y: ', -153485)
# ('x: ', 115117)
# ('y: ', -153489)
# ('x: ', 115120)
# ('y: ', -153493)
# ('x: ', 115123)
# ('y: ', -153497)
# ('x: ', 115126)
# ('y: ', -153501)
# ('x: ', 115129)
# ('y: ', -153505)
# ('x: ', 115132)
# ('y: ', -153509)
# ('x: ', 115135)
# ('y: ', -153513)
# ('x: ', 115138)
# ('y: ', -153517)
# ('x: ', 115141)
# ('y: ', -153521)
# ('x: ', 115144)
# ('y: ', -153525)
# ('x: ', 115147)
# ('y: ', -153529)
# ('x: ', 115150)
# ('y: ', -153533)
# ('x: ', 115153)
# ('y: ', -153537)
# ('x: ', 115156)
# ('y: ', -153541)
# ('x: ', 115159)
# ('y: ', -153545)
# ('x: ', 115162)
# ('y: ', -153549)
# ('x: ', 115165)
# ('y: ', -153553)
# ('x: ', 115168)
# ('y: ', -153557)
# ('x: ', 115171)
# ('y: ', -153561)
# ('x: ', 115174)
# ('y: ', -153565)
# ('x: ', 115177)
# ('y: ', -153569)
# ('x: ', 115180)
# ('y: ', -153573)
# ('x: ', 115183)
# ('y: ', -153577)
# ('x: ', 115186)
# ('y: ', -153581)
# ('x: ', 115189)
# ('y: ', -153585)
# ('x: ', 115192)
# ('y: ', -153589)
# ('x: ', 115195)
# ('y: ', -153593)
# ('x: ', 115198)
# ('y: ', -153597)
# ('x: ', 115201)
# ('y: ', -153601)
# ('x: ', 115204)
# ('y: ', -153605)
# ('x: ', 115207)
# ('y: ', -153609)
# ('x: ', 115210)
# ('y: ', -153613)
# ('x: ', 115213)
# ('y: ', -153617)
# ('x: ', 115216)
# ('y: ', -153621)
# ('x: ', 115219)
# ('y: ', -153625)
# ('x: ', 115222)
# ('y: ', -153629)
# ('x: ', 115225)
# ('y: ', -153633)
# ('x: ', 115228)
# ('y: ', -153637)
# ('x: ', 115231)
# ('y: ', -153641)
# ('x: ', 115234)
# ('y: ', -153645)
# ('x: ', 115237)
# ('y: ', -153649)
# ('x: ', 115240)
# ('y: ', -153653)
# ('x: ', 115243)
# ('y: ', -153657)
# ('x: ', 115246)
# ('y: ', -153661)
# ('x: ', 115249)
# ('y: ', -153665)
# ('x: ', 115252)
# ('y: ', -153669)
# ('x: ', 115255)
# ('y: ', -153673)
# ('x: ', 115258)
# ('y: ', -153677)
# ('x: ', 115261)
# ('y: ', -153681)
# ('x: ', 115264)
# ('y: ', -153685)
# ('x: ', 115267)
# ('y: ', -153689)
# ('x: ', 115270)
# ('y: ', -153693)
# ('x: ', 115273)
# ('y: ', -153697)
# ('x: ', 115276)
# ('y: ', -153701)
# ('x: ', 115279)
# ('y: ', -153705)
# ('x: ', 115282)
# ('y: ', -153709)
# ('x: ', 115285)
# ('y: ', -153713)
# ('x: ', 115288)
# ('y: ', -153717)
# ('x: ', 115291)
# ('y: ', -153721)
# ('x: ', 115294)
# ('y: ', -153725)
# ('x: ', 115297)
# ('y: ', -153729)
# ('x: ', 115300)
# ('y: ', -153733)
# ('x: ', 115303)
# ('y: ', -153737)
# ('x: ', 115306)
# ('y: ', -153741)
# ('x: ', 115309)
# ('y: ', -153745)
# ('x: ', 115312)
# ('y: ', -153749)
# ('x: ', 115315)
# ('y: ', -153753)
# ('x: ', 115318)
# ('y: ', -153757)
# ('x: ', 115321)
# ('y: ', -153761)
# ('x: ', 115324)
# ('y: ', -153765)
# ('x: ', 115327)
# ('y: ', -153769)
# ('x: ', 115330)
# ('y: ', -153773)
# ('x: ', 115333)
# ('y: ', -153777)
# ('x: ', 115336)
# ('y: ', -153781)
# ('x: ', 115339)
# ('y: ', -153785)
# ('x: ', 115342)
# ('y: ', -153789)
# ('x: ', 115345)
# ('y: ', -153793)
# ('x: ', 115348)
# ('y: ', -153797)
# ('x: ', 115351)
# ('y: ', -153801)
# ('x: ', 115354)
# ('y: ', -153805)
# ('x: ', 115357)
# ('y: ', -153809)
# ('x: ', 115360)
# ('y: ', -153813)
# ('x: ', 115363)
# ('y: ', -153817)
# ('x: ', 115366)
# ('y: ', -153821)
# ('x: ', 115369)
# ('y: ', -153825)
# ('x: ', 115372)
# ('y: ', -153829)
# ('x: ', 115375)
# ('y: ', -153833)
# ('x: ', 115378)
# ('y: ', -153837)
# ('x: ', 115381)
# ('y: ', -153841)
# ('x: ', 115384)
# ('y: ', -153845)
# ('x: ', 115387)
# ('y: ', -153849)
# ('x: ', 115390)
# ('y: ', -153853)
# ('x: ', 115393)
# ('y: ', -153857)
# ('x: ', 115396)
# ('y: ', -153861)
# ('x: ', 115399)
# ('y: ', -153865)
# ('x: ', 115402)
# ('y: ', -153869)
# ('x: ', 115405)
# ('y: ', -153873)
# ('x: ', 115408)
# ('y: ', -153877)
# ('x: ', 115411)
# ('y: ', -153881)
# ('x: ', 115414)
# ('y: ', -153885)
# ('x: ', 115417)
# ('y: ', -153889)
# ('x: ', 115420)
# ('y: ', -153893)
# ('x: ', 115423)
# ('y: ', -153897)
# ('x: ', 115426)
# ('y: ', -153901)
# ('x: ', 115429)
# ('y: ', -153905)
# ('x: ', 115432)
# ('y: ', -153909)
# ('x: ', 115435)
# ('y: ', -153913)
# ('x: ', 115438)
# ('y: ', -153917)
# ('x: ', 115441)
# ('y: ', -153921)
# ('x: ', 115444)
# ('y: ', -153925)
# ('x: ', 115447)
# ('y: ', -153929)
# ('x: ', 115450)
# ('y: ', -153933)
# ('x: ', 115453)
# ('y: ', -153937)
# ('x: ', 115456)
# ('y: ', -153941)
# ('x: ', 115459)
# ('y: ', -153945)
# ('x: ', 115462)
# ('y: ', -153949)
# ('x: ', 115465)
# ('y: ', -153953)
# ('x: ', 115468)
# ('y: ', -153957)
# ('x: ', 115471)
# ('y: ', -153961)
# ('x: ', 115474)
# ('y: ', -153965)
# ('x: ', 115477)
# ('y: ', -153969)
# ('x: ', 115480)
# ('y: ', -153973)
# ('x: ', 115483)
# ('y: ', -153977)
# ('x: ', 115486)
# ('y: ', -153981)
# ('x: ', 115489)
# ('y: ', -153985)
# ('x: ', 115492)
# ('y: ', -153989)
# ('x: ', 115495)
# ('y: ', -153993)
# ('x: ', 115498)
# ('y: ', -153997)
# ('x: ', 115501)
# ('y: ', -154001)
# ('x: ', 115504)
# ('y: ', -154005)
# ('x: ', 115507)
# ('y: ', -154009)
# ('x: ', 115510)
# ('y: ', -154013)
# ('x: ', 115513)
# ('y: ', -154017)
# ('x: ', 115516)
# ('y: ', -154021)
# ('x: ', 115519)
# ('y: ', -154025)
# ('x: ', 115522)
# ('y: ', -154029)
# ('x: ', 115525)
# ('y: ', -154033)
# ('x: ', 115528)
# ('y: ', -154037)
# ('x: ', 115531)
# ('y: ', -154041)
# ('x: ', 115534)
# ('y: ', -154045)
# ('x: ', 115537)
# ('y: ', -154049)
# ('x: ', 115540)
# ('y: ', -154053)
# ('x: ', 115543)
# ('y: ', -154057)
# ('x: ', 115546)
# ('y: ', -154061)
# ('x: ', 115549)
# ('y: ', -154065)
# ('x: ', 115552)
# ('y: ', -154069)
# ('x: ', 115555)
# ('y: ', -154073)
# ('x: ', 115558)
# ('y: ', -154077)
# ('x: ', 115561)
# ('y: ', -154081)
# ('x: ', 115564)
# ('y: ', -154085)
# ('x: ', 115567)
# ('y: ', -154089)
# ('x: ', 115570)
# ('y: ', -154093)
# ('x: ', 115573)
# ('y: ', -154097)
# ('x: ', 115576)
# ('y: ', -154101)
# ('x: ', 115579)
# ('y: ', -154105)
# ('x: ', 115582)
# ('y: ', -154109)
# ('x: ', 115585)
# ('y: ', -154113)
# ('x: ', 115588)
# ('y: ', -154117)
# ('x: ', 115591)
# ('y: ', -154121)
# ('x: ', 115594)
# ('y: ', -154125)
# ('x: ', 115597)
# ('y: ', -154129)
# ('x: ', 115600)
# ('y: ', -154133)
# ('x: ', 115603)
# ('y: ', -154137)
# ('x: ', 115606)
# ('y: ', -154141)
# ('x: ', 115609)
# ('y: ', -154145)
# ('x: ', 115612)
# ('y: ', -154149)
# ('x: ', 115615)
# ('y: ', -154153)
# ('x: ', 115618)
# ('y: ', -154157)
# ('x: ', 115621)
# ('y: ', -154161)
# ('x: ', 115624)
# ('y: ', -154165)
# ('x: ', 115627)
# ('y: ', -154169)
# ('x: ', 115630)
# ('y: ', -154173)
# ('x: ', 115633)
# ('y: ', -154177)
# ('x: ', 115636)
# ('y: ', -154181)
# ('x: ', 115639)
# ('y: ', -154185)
# ('x: ', 115642)
# ('y: ', -154189)
# ('x: ', 115645)
# ('y: ', -154193)
# ('x: ', 115648)
# ('y: ', -154197)
# ('x: ', 115651)
# ('y: ', -154201)
# ('x: ', 115654)
# ('y: ', -154205)
# ('x: ', 115657)
# ('y: ', -154209)
# ('x: ', 115660)
# ('y: ', -154213)
# ('x: ', 115663)
# ('y: ', -154217)
# ('x: ', 115666)
# ('y: ', -154221)
# ('x: ', 115669)
# ('y: ', -154225)
# ('x: ', 115672)
# ('y: ', -154229)
# ('x: ', 115675)
# ('y: ', -154233)
# ('x: ', 115678)
# ('y: ', -154237)
# ('x: ', 115681)
# ('y: ', -154241)
# ('x: ', 115684)
# ('y: ', -154245)
# ('x: ', 115687)
# ('y: ', -154249)
# ('x: ', 115690)
# ('y: ', -154253)
# ('x: ', 115693)
# ('y: ', -154257)
# ('x: ', 115696)
# ('y: ', -154261)
# ('x: ', 115699)
# ('y: ', -154265)
# ('x: ', 115702)
# ('y: ', -154269)
# ('x: ', 115705)
# ('y: ', -154273)
# ('x: ', 115708)
# ('y: ', -154277)
# ('x: ', 115711)
# ('y: ', -154281)
# ('x: ', 115714)
# ('y: ', -154285)
# ('x: ', 115717)
# ('y: ', -154289)
# ('x: ', 115720)
# ('y: ', -154293)
# ('x: ', 115723)
# ('y: ', -154297)
# ('x: ', 115726)
# ('y: ', -154301)
# ('x: ', 115729)
# ('y: ', -154305)
# ('x: ', 115732)
# ('y: ', -154309)
# ('x: ', 115735)
# ('y: ', -154313)
# ('x: ', 115738)
# ('y: ', -154317)
# ('x: ', 115741)
# ('y: ', -154321)
# ('x: ', 115744)
# ('y: ', -154325)
# ('x: ', 115747)
# ('y: ', -154329)
# ('x: ', 115750)
# ('y: ', -154333)
# ('x: ', 115753)
# ('y: ', -154337)
# ('x: ', 115756)
# ('y: ', -154341)
# ('x: ', 115759)
# ('y: ', -154345)
# ('x: ', 115762)
# ('y: ', -154349)
# ('x: ', 115765)
# ('y: ', -154353)
# ('x: ', 115768)
# ('y: ', -154357)
# ('x: ', 115771)
# ('y: ', -154361)
# ('x: ', 115774)
# ('y: ', -154365)
# ('x: ', 115777)
# ('y: ', -154369)
# ('x: ', 115780)
# ('y: ', -154373)
# ('x: ', 115783)
# ('y: ', -154377)
# ('x: ', 115786)
# ('y: ', -154381)
# ('x: ', 115789)
# ('y: ', -154385)
# ('x: ', 115792)
# ('y: ', -154389)
# ('x: ', 115795)
# ('y: ', -154393)
# ('x: ', 115798)
# ('y: ', -154397)
# ('x: ', 115801)
# ('y: ', -154401)
# ('x: ', 115804)
# ('y: ', -154405)
# ('x: ', 115807)
# ('y: ', -154409)
# ('x: ', 115810)
# ('y: ', -154413)
# ('x: ', 115813)
# ('y: ', -154417)
# ('x: ', 115816)
# ('y: ', -154421)
# ('x: ', 115819)
# ('y: ', -154425)
# ('x: ', 115822)
# ('y: ', -154429)
# ('x: ', 115825)
# ('y: ', -154433)
# ('x: ', 115828)
# ('y: ', -154437)
# ('x: ', 115831)
# ('y: ', -154441)
# ('x: ', 115834)
# ('y: ', -154445)
# ('x: ', 115837)
# ('y: ', -154449)
# ('x: ', 115840)
# ('y: ', -154453)
# ('x: ', 115843)
# ('y: ', -154457)
# ('x: ', 115846)
# ('y: ', -154461)
# ('x: ', 115849)
# ('y: ', -154465)
# ('x: ', 115852)
# ('y: ', -154469)
# ('x: ', 115855)
# ('y: ', -154473)
# ('x: ', 115858)
# ('y: ', -154477)
# ('x: ', 115861)
# ('y: ', -154481)
# ('x: ', 115864)
# ('y: ', -154485)
# ('x: ', 115867)
# ('y: ', -154489)
# ('x: ', 115870)
# ('y: ', -154493)
# ('x: ', 115873)
# ('y: ', -154497)
# ('x: ', 115876)
# ('y: ', -154501)
# ('x: ', 115879)
# ('y: ', -154505)
# ('x: ', 115882)
# ('y: ', -154509)
# ('x: ', 115885)
# ('y: ', -154513)
# ('x: ', 115888)
# ('y: ', -154517)
# ('x: ', 115891)
# ('y: ', -154521)
# ('x: ', 115894)
# ('y: ', -154525)
# ('x: ', 115897)
# ('y: ', -154529)
# ('x: ', 115900)
# ('y: ', -154533)
# ('x: ', 115903)
# ('y: ', -154537)
# ('x: ', 115906)
# ('y: ', -154541)
# ('x: ', 115909)
# ('y: ', -154545)
# ('x: ', 115912)
# ('y: ', -154549)
# ('x: ', 115915)
# ('y: ', -154553)
# ('x: ', 115918)
# ('y: ', -154557)
# ('x: ', 115921)
# ('y: ', -154561)
# ('x: ', 115924)
# ('y: ', -154565)
# ('x: ', 115927)
# ('y: ', -154569)
# ('x: ', 115930)
# ('y: ', -154573)
# ('x: ', 115933)
# ('y: ', -154577)
# ('x: ', 115936)
# ('y: ', -154581)
# ('x: ', 115939)
# ('y: ', -154585)
# ('x: ', 115942)
# ('y: ', -154589)
# ('x: ', 115945)
# ('y: ', -154593)
# ('x: ', 115948)
# ('y: ', -154597)
# ('x: ', 115951)
# ('y: ', -154601)
# ('x: ', 115954)
# ('y: ', -154605)
# ('x: ', 115957)
# ('y: ', -154609)
# ('x: ', 115960)
# ('y: ', -154613)
# ('x: ', 115963)
# ('y: ', -154617)
# ('x: ', 115966)
# ('y: ', -154621)
# ('x: ', 115969)
# ('y: ', -154625)
# ('x: ', 115972)
# ('y: ', -154629)
# ('x: ', 115975)
# ('y: ', -154633)
# ('x: ', 115978)
# ('y: ', -154637)
# ('x: ', 115981)
# ('y: ', -154641)
# ('x: ', 115984)
# ('y: ', -154645)
# ('x: ', 115987)
# ('y: ', -154649)
# ('x: ', 115990)
# ('y: ', -154653)
# ('x: ', 115993)
# ('y: ', -154657)
# ('x: ', 115996)
# ('y: ', -154661)
# ('x: ', 115999)
# ('y: ', -154665)
# ('x: ', 116002)
# ('y: ', -154669)
# ('x: ', 116005)
# ('y: ', -154673)
# ('x: ', 116008)
# ('y: ', -154677)
# ('x: ', 116011)
# ('y: ', -154681)
# ('x: ', 116014)
# ('y: ', -154685)
# ('x: ', 116017)
# ('y: ', -154689)
# ('x: ', 116020)
# ('y: ', -154693)
# ('x: ', 116023)
# ('y: ', -154697)
# ('x: ', 116026)
# ('y: ', -154701)
# ('x: ', 116029)
# ('y: ', -154705)
# ('x: ', 116032)
# ('y: ', -154709)
# ('x: ', 116035)
# ('y: ', -154713)
# ('x: ', 116038)
# ('y: ', -154717)
# ('x: ', 116041)
# ('y: ', -154721)
# ('x: ', 116044)
# ('y: ', -154725)
# ('x: ', 116047)
# ('y: ', -154729)
# ('x: ', 116050)
# ('y: ', -154733)
# ('x: ', 116053)
# ('y: ', -154737)
# ('x: ', 116056)
# ('y: ', -154741)
# ('x: ', 116059)
# ('y: ', -154745)
# ('x: ', 116062)
# ('y: ', -154749)
# ('x: ', 116065)
# ('y: ', -154753)
# ('x: ', 116068)
# ('y: ', -154757)
# ('x: ', 116071)
# ('y: ', -154761)
# ('x: ', 116074)
# ('y: ', -154765)
# ('x: ', 116077)
# ('y: ', -154769)
# ('x: ', 116080)
# ('y: ', -154773)
# ('x: ', 116083)
# ('y: ', -154777)
# ('x: ', 116086)
# ('y: ', -154781)
# ('x: ', 116089)
# ('y: ', -154785)
# ('x: ', 116092)
# ('y: ', -154789)
# ('x: ', 116095)
# ('y: ', -154793)
# ('x: ', 116098)
# ('y: ', -154797)
# ('x: ', 116101)
# ('y: ', -154801)
# ('x: ', 116104)
# ('y: ', -154805)
# ('x: ', 116107)
# ('y: ', -154809)
# ('x: ', 116110)
# ('y: ', -154813)
# ('x: ', 116113)
# ('y: ', -154817)
# ('x: ', 116116)
# ('y: ', -154821)
# ('x: ', 116119)
# ('y: ', -154825)
# ('x: ', 116122)
# ('y: ', -154829)
# ('x: ', 116125)
# ('y: ', -154833)
# ('x: ', 116128)
# ('y: ', -154837)
# ('x: ', 116131)
# ('y: ', -154841)
# ('x: ', 116134)
# ('y: ', -154845)
# ('x: ', 116137)
# ('y: ', -154849)
# ('x: ', 116140)
# ('y: ', -154853)
# ('x: ', 116143)
# ('y: ', -154857)
# ('x: ', 116146)
# ('y: ', -154861)
# ('x: ', 116149)
# ('y: ', -154865)
# ('x: ', 116152)
# ('y: ', -154869)
# ('x: ', 116155)
# ('y: ', -154873)
# ('x: ', 116158)
# ('y: ', -154877)
# ('x: ', 116161)
# ('y: ', -154881)
# ('x: ', 116164)
# ('y: ', -154885)
# ('x: ', 116167)
# ('y: ', -154889)
# ('x: ', 116170)
# ('y: ', -154893)
# ('x: ', 116173)
# ('y: ', -154897)
# ('x: ', 116176)
# ('y: ', -154901)
# ('x: ', 116179)
# ('y: ', -154905)
# ('x: ', 116182)
# ('y: ', -154909)
# ('x: ', 116185)
# ('y: ', -154913)
# ('x: ', 116188)
# ('y: ', -154917)
# ('x: ', 116191)
# ('y: ', -154921)
# ('x: ', 116194)
# ('y: ', -154925)
# ('x: ', 116197)
# ('y: ', -154929)
# ('x: ', 116200)
# ('y: ', -154933)
# ('x: ', 116203)
# ('y: ', -154937)
# ('x: ', 116206)
# ('y: ', -154941)
# ('x: ', 116209)
# ('y: ', -154945)
# ('x: ', 116212)
# ('y: ', -154949)
# ('x: ', 116215)
# ('y: ', -154953)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-eb208e112c3b> in <module>()
#       5     print("x: ", x)
#       6     y -= 4
# ----> 7     print("y: ", y)
#
# /home/david/anaconda2/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /home/david/anaconda2/lib/python2.7/site-packages/ipykernel/iostream.pyc in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /home/david/anaconda2/lib/python2.7/site-packages/zmq/sugar/socket.pyc in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /home/david/anaconda2/lib/python2.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#      10     """
#      11     cdef int errno = zmq_errno()
# ---> 12     PyErr_CheckSignals()
#      13     if rc == -1: # if rc < -1, it's a bug in libzmq. Should we warn?
#      14         if errno == EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Complex expressions
# Writing complex expressions is fine as long as they are readable, but they can be hard to debug. It is often a good idea to break a complex expression into a series of assignments to temporary variables.
#
# We've already dealt with this once when we were measuring voice pitch.

# %% [markdown]
# We `imported` some libraries and loaded some sounds

# %%
import glob
import parselmouth
from parselmouth.praat import call
wav_file = '/home/david/work/stimuli/sample_sounds/m4195_vowels.wav'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-bd0bf24f65d5> in <module>()
#       1 import glob
# ----> 2 import parselmouth
#       3 from parselmouth.praat import call
#       4 wav_file = '/home/david/work/stimuli/sample_sounds/m4195_vowels.wav'
#
# ImportError: No module named parselmouth

# %% [markdown]
# Then we wrote some crazy expression that was super hard to understand, and I told you how good it was to write expressions like that.

# %%
print(call(parselmouth.Sound(wav_file).to_pitch(), "Get mean", 0, 0, "Hertz"))

# %% [markdown]
# But then I showed you how to break it down into pieces to understand what's happening.

# %% [markdown]
# We loaded a sound

# %%
sound = parselmouth.Sound(wav_file)

# %% [markdown]
# We measured the pitch of the sound

# %%
pitch = call(sound, "To Pitch", 0.0, 60, 500)

# %% [markdown]
# We calculated the mean pitch

# %%
mean_pitch = call(pitch, "Get mean", 0, 0, "Hertz")

# %% [markdown]
# Then we printed the result

# %%
print(mean_pitcn)

# %% [markdown]
# You can always re-write complicated expressions as individual operations.  That will help you understand what the expression does, and to fix any errors that are occuring when using it.

# %% [markdown]
# ## Order of operations
#
# Remember that all else equal, expressions are evaluated left to right.  Therefore it's important to use parentheses to block your equations and make sure they evaluate properly so you don't get math errors.
#
# - Python uses PEMDAS is
#     - `P`arentheses
#     - `E`xponents
#     - `M`ultiplication and `D`ivision
#         - Multiplication and division have the same precedence
#         - The leftmost goes first
#     - `A`ddition and `S`ubtractraction
#         - Addition and subtraction have the same precedence
#         - The leftmost goes first
#
# You can always break the equation down into pieces to help understand what's going on, like we did in the divide by zero example.
#
#
#
# <div class="section" id="no-i-really-need-help">
# <h2>No, I really need help.<a class="headerlink" href="#no-i-really-need-help" title="Permalink to this headline">¶</a></h2>
# <p>It happens. Even the best programmers occasionally get stuck.  Sometimes you
# work on a program so long that you can&#8217;t see the error.  A fresh pair of eyes
# is just the thing.</p>
# <p>Before you bring someone else in, make sure you have exhausted the techniques
# described here. Your program should be as simple as possible, and you should be
# working on the smallest input that causes the error. You should have <tt class="docutils literal"><span class="pre">print</span></tt>
# statements in the appropriate places (and the output they produce should be
# comprehensible). You should understand the problem well enough to describe it
# concisely.</p>
# <p>When you bring someone in to help, be sure to give them the information they
# need:</p>
# <ol class="arabic simple">
# <li>If there is an error message, what is it and what part of the program does
# it indicate?</li>
# <li>What was the last thing you did before this error occurred? What were the
# last lines of code that you wrote, or what is the new test case that fails?</li>
# <li>What have you tried so far, and what have you learned?</li>
# </ol>
# <p>When you find the bug, take a second to think about what you could have done to
# find it faster. Next time you see something similar, you will be able to find
# the bug more quickly.</p>
# <p>Remember, the goal is not just to make the program work. The goal is to learn
# how to make the program work.</p>
# </div>
# </div>

# %% [markdown]
# additional source: http://www.openbookproject.net/thinkcs/python/english2e/app_a.html

# %% [markdown]
# # What to do if doing print statments and stepping through doesn't work and you can't run your program?

# %% [markdown]
# - Start from scratch
#     - Add each piece of code line by line
# - When writing loops, make sure the code inside a loop works before wrapping it in a loop
# - When writing functions make sure the:
#     - code inside the function works
#     - inputs into the function are correct
#     - the code executing function is correct
#     - you are properly dealing with the function output
# - Is there something that isn't happening that is supposed to happen?
#    - Figure out if something is
#        - missing
#        - called incorrectly (e.g. typos, name errors)
#        - misplaced
# - Is something that is happening that shouldn't happen?
#     - Is something in the wrong place in a loop
#     - Are you in the correct namespace
#     - Are you using the function correctly
#     - Is the function written correctly?

# %% [markdown]
# # What if that doesn't work and I still can't figure it out?

# %% [markdown]
# ## Take a break
#
# - If you are frustrated or angry
# - If you believe your computer is out to get you
# - If you can't get it no matter what you do
#
# ## Break out of a mental loop
#
# It's okay to put it down and try again tomorrow.  Chances are you'll think of the solution just before you go to sleep, or when you wake up.  Your mind might just need some time to get out of a loop.

# %% [markdown]
# ## Ask a friend or classmate

# %% [markdown]
# ## Ask your Instructors
# We probably know the answers to the exercises we assigned.  Don't be afraid to ask us for help. You can always ask Dr. Feinberg for help coding, even if it's not for this class.

# %% [markdown]
# ## Googling the problem
#
# It's totally legit to search the web for your problem.  Here are some things that are useful:
# - Type your problem, or copy and paste your error message into google
#     - Type `Python` when you do this to make sure you get help for Python and not some other programming language
#     - The more you do this, the more google learns what you're doing, and the better your search results become
# - Search for YouTube videos
# - Ask for help on <a href = "https://stackoverflow.com">Stack Overflow</a> or Reddit's <a href = "https://reddit.com/r/learnpython">/r/learnpython</a>
#     - These are sites where you can post your code, and people will try it out, figure out the problem, and help you learn how to fix it.
#     - Read the code that you see.  Retype it. Internalize it. Don't just copy and paste the answers.
#     - You might get an exercise correct in class, but you won't learn anything.
# - It's going to take some time getting used to understanding other people's errors and how they apply to you. Keep on trying and the more you code, and the more errors you look up, the more you'll learn and the easier it will get.
